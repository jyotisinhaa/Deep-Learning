# %% [markdown]
# <h3><b> Importing Library</b></h3>

# %%
# Importing Libraries
from __future__ import print_function
import os
import math 
import cv2 
import tensorflow as tf
import keras
from keras import backend as K
import numpy as np
from keras.datasets import cifar100
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras import optimizers
from keras.utils import np_utils
from keras.optimizers import SGD 
from keras.callbacks import LearningRateScheduler
from keras import regularizers
from matplotlib import pyplot
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from keras.models import Model
from keras.layers import Conv2D, MaxPool2D, Dropout, Dense, Input, concatenate, GlobalAveragePooling2D, AveragePooling2D,Flatten

# %% [markdown]
# <h3><b> Importing Dataset</b><h3>

# %%
# Load dataset
(X_train, y_train), (X_test, y_test) = cifar100.load_data()
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 2s 0us/step
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# <h3><b> Preprocessing of the dataset</b></h3>

# %%
# Normalize the dataset
X_train = X_train/255
X_test = X_test/255

# %%
#Converting the testing and training dataset into float
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# Convert training and test labels to one hot matrices
y_train = keras.utils.to_categorical(y_train, 100)
y_test = keras.utils.to_categorical(y_test, 100)
print(y_train.shape)
# Out:
# (50000, 100)

# %% [markdown]
# <h3><b> Model Architecure</b></h3>

# %%
def inception_moduleA(x,
                     filters_1x1,
                     filters_3x3_reduce,
                     filters_3x3,
                     filters_5x5_reduce,
                     filters_3x3a,
                      filters_3x3b,
                  
                     filters_pool_proj,
                     name=None):
    
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='elu')(x)
    
    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='elu')(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='elu')(conv_3x3)

    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='elu')(x)
    conv_3x3a = Conv2D(filters_3x3a, (3, 3), padding='same', activation='elu')(conv_5x5)
    conv_3x3b = Conv2D(filters_3x3b, (3, 3), padding='same', activation='elu')(conv_3x3a)
    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='elu')(pool_proj)

    output = concatenate([conv_1x1, conv_3x3, conv_3x3a, pool_proj], axis=-1, name=name)
    
    return output


def inception_moduleB(x,
                     filters_1x1modb,
                     filters_3x3_reducemodb,
                     filters_1x3modb,
                     filters_3x1modb,
                     filters_5x5_reducemodb,
                     filters_1x3amodb,
                      filters_3x1amodb,
                     filters_1x3bmodb,
                      filters_3x1bmodb,
                  
                     filters_pool_proj,
                     name=None):
    
    conv_1x1modb = Conv2D(filters_1x1modb, (1, 1), padding='same', activation='elu')(x)
    
    conv_3x3modb = Conv2D(filters_3x3_reducemodb, (1, 1), padding='same', activation='elu')(x)
    conv_1x3modb = Conv2D(filters_1x3modb, (1, 3), padding='same', activation='elu')(conv_3x3modb)
    conv_3x1modb = Conv2D(filters_3x1modb, (3, 1), padding='same', activation='elu')(conv_1x3modb)

    conv_5x5modb = Conv2D(filters_5x5_reducemodb, (1, 1), padding='same', activation='elu')(x)
    conv_1x3amodb = Conv2D(filters_1x3amodb, (1, 3), padding='same', activation='elu')(conv_5x5modb)
    conv_3x1amodb = Conv2D(filters_3x1amodb, (3, 1), padding='same', activation='elu')(conv_1x3amodb)
    conv_1x3bmodb = Conv2D(filters_1x3bmodb, (1, 3), padding='same', activation='elu')(conv_3x1amodb)
    conv_3x1bmodb = Conv2D(filters_3x1bmodb, (3, 1), padding='same', activation='elu')(conv_1x3bmodb)


    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)


    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='elu')(pool_proj)

    output = concatenate([conv_1x1modb, conv_3x1modb, conv_3x1bmodb, pool_proj], axis=-1, name=name)
    
    return output


def inception_moduleC(x,
                     filters_1x1modc,
                      filters_3x3_reducemodc,
                     filters_1x3modc,
                      filters_3x1modc,
                     filters_5x5_reducemodc,
                        filters_3x3amodc,
                      filters_1x3amodc,
                       filters_3x1amodc,
                      
                   
                     filters_pool_proj,
                     name=None):
    
    conv_1x1modc = Conv2D(filters_1x1modc, (1, 1), padding='same', activation='elu')(x)
    
    conv_3x3modc = Conv2D(filters_3x3_reducemodc, (1, 1), padding='same', activation='elu')(x)
    conv_1x3modc = Conv2D(filters_1x3modc, (1, 3), padding='same', activation='elu')(conv_3x3modc)
    conv_3x1modc = Conv2D(filters_3x1modc, (3, 1), padding='same', activation='elu')(conv_1x3modc)

    conv_5x5modc = Conv2D(filters_5x5_reducemodc, (1, 1), padding='same', activation='elu')(x)
    conv_3x3amodc = Conv2D(filters_3x3amodc, (1, 1), padding='same', activation='elu')(conv_5x5modc)

    conv_1x3amodc = Conv2D(filters_1x3amodc, (1, 3), padding='same', activation='elu')(conv_3x3amodc)
    conv_3x1amodc = Conv2D(filters_3x1amodc, (3, 1), padding='same', activation='elu')(conv_1x3amodc)



    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)


    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='elu')(pool_proj)

    output = concatenate([conv_1x1modc,conv_1x3modc, conv_3x1modc, conv_1x3amodc,conv_3x1amodc, pool_proj], axis=-1, name=name)
    
    return output

# %%
input_layer = Input(shape=(32, 32, 3))

x = Conv2D(64, (3, 3), padding='same', strides=(2, 2), activation='elu', name='conv_1a_3x3/2')(input_layer)
x = Conv2D(64, (3, 3), padding='same', strides=(1, 1), activation='elu', name='conv_2a_3x3/1')(x)
x = Conv2D(64, (3, 3), padding='same', strides=(1, 1), activation='elu', name='conv_3a_3x3/1')(x)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_2_3x3/2')(x)
x = Conv2D(64, (3, 3), padding='same', strides=(1, 1), activation='elu', name='conv_4a_3x3/1')(x)
x = Conv2D(64, (3, 3), padding='same', strides=(2, 2), activation='elu', name='conv_5a_3x3/2')(x)
x = Conv2D(64, (3, 3), padding='same', strides=(1, 1), activation='elu', name='conv_6a_3x3/1')(x)

x = inception_moduleA(x,
                     filters_1x1=64,
                     filters_3x3_reduce=96,
                     filters_3x3=128,
                     filters_5x5_reduce=16,
                     filters_3x3a=32,
                     filters_3x3b=32,
                     filters_pool_proj=32,
                     name='inception_3a')
x = inception_moduleA(x,
                     filters_1x1=64,
                     filters_3x3_reduce=96,
                     filters_3x3=128,
                     filters_5x5_reduce=16,
                     filters_3x3a=32,
                     filters_3x3b=32,
                     filters_pool_proj=32,
                     name='inception_3aa')

#I am commenting the numbers of times module A, ModuleB is called as it is helping to increase my accuracy.In original InceptionV2 architecture ModuleA is called
#3 times, ModuleB is called 5 times and ModuleC is called 2 times:-
# x = inception_moduleA(x,
#                      filters_1x1=64,
#                      filters_3x3_reduce=96,
#                      filters_3x3=128,
#                      filters_5x5_reduce=16,
#                      filters_3x3a=32,
#                      filters_3x3b=32,
#                      filters_pool_proj=32,
#                      name='inception_3aaa')

x = inception_moduleB(x,
                     filters_1x1modb=64,
                     filters_3x3_reducemodb=96,
                     filters_1x3modb=128,
                     filters_3x1modb=128,
                     filters_5x5_reducemodb=16,
                     filters_1x3amodb=128,
                     filters_3x1amodb=128,
                     filters_1x3bmodb=128,
                     filters_3x1bmodb=128,
                   filters_pool_proj=32,
                     name='inception_4a')
x = inception_moduleB(x,
                     filters_1x1modb=64,
                     filters_3x3_reducemodb=96,
                     filters_1x3modb=128,
                     filters_3x1modb=128,
                     filters_5x5_reducemodb=16,
                     filters_1x3amodb=128,
                     filters_3x1amodb=128,
                     filters_1x3bmodb=128,
                     filters_3x1bmodb=128,
                     filters_pool_proj=32,
                     name='inception_4aa')
x = inception_moduleB(x,
                     filters_1x1modb=64,
                     filters_3x3_reducemodb=96,
                     filters_1x3modb=128,
                     filters_3x1modb=128,
                     filters_5x5_reducemodb=16,
                     filters_1x3amodb=128,
                     filters_3x1amodb=128,
                     filters_1x3bmodb=128,
                     filters_3x1bmodb=128,
                      filters_pool_proj=32,
             
                     name='inception_4aaa')
#I am commenting the numbers of times module A, ModuleB is called as it is helping to increase my accuracy.In original InceptionV2 architecture ModuleA is called
#3 times, ModuleB is called 5 times and ModuleC is called 2 times:-
# x = inception_moduleB(x,
#                      filters_1x1modb=64,
#                      filters_3x3_reducemodb=96,
#                      filters_1x3modb=128,
#                      filters_3x1modb=128,
#                      filters_5x5_reducemodb=16,
#                      filters_1x3amodb=128,
#                      filters_3x1amodb=128,
#                      filters_1x3bmodb=128,
#                      filters_3x1bmodb=128,
#                      filters_pool_proj=32,
#                      name='inception_4aaaa')
# x = inception_moduleB(x,
#                      filters_1x1modb=64,
#                      filters_3x3_reducemodb=96,
#                      filters_1x3modb=128,
#                      filters_3x1modb=128,
#                      filters_5x5_reducemodb=16,
#                      filters_1x3amodb=128,
#                      filters_3x1amodb=128,
#                      filters_1x3bmodb=128,
#                      filters_3x1bmodb=128,
#                      filters_pool_proj=32,
#                      name='inception_4aaaaa')

x = inception_moduleC(x,
                     filters_1x1modc=64,
                     filters_3x3_reducemodc=96,
                     filters_1x3modc=128,
                     filters_3x1modc=128,
                     filters_5x5_reducemodc=16,
                     filters_3x3amodc=128,
                     filters_1x3amodc=128,
                     filters_3x1amodc=128,
                     filters_pool_proj=32,
                    
                     name='inception_5a')
x = inception_moduleC(x,
                     filters_1x1modc=64,
                     filters_3x3_reducemodc=96,
                     filters_1x3modc=128,
                     filters_3x1modc=128,
                     filters_5x5_reducemodc=16,
                     filters_3x3amodc=128,
                     filters_1x3amodc=128,
                     filters_3x1amodc=128,
                     filters_pool_proj=32,
             
                     name='inception_5aa')

x = GlobalAveragePooling2D(name='avg_pool_5_3x3/1')(x)
x = Dropout(0.4)(x)
x = Flatten()(x)
output = Dense(100, activation='softmax', name='output')(x)

# %%
model = Model(input_layer,  output)

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv_1a_3x3/2 (Conv2D)          (None, 16, 16, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv_2a_3x3/1 (Conv2D)          (None, 16, 16, 64)   36928       conv_1a_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv_3a_3x3/1 (Conv2D)          (None, 16, 16, 64)   36928       conv_2a_3x3/1[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 8, 8, 64)     0           conv_3a_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv_4a_3x3/1 (Conv2D)          (None, 8, 8, 64)     36928       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv_5a_3x3/2 (Conv2D)          (None, 4, 4, 64)     36928       conv_4a_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv_6a_3x3/1 (Conv2D)          (None, 4, 4, 64)     36928       conv_5a_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 4, 4, 96)     6240        conv_6a_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 4, 4, 16)     1040        conv_6a_3x3/1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 4, 4, 64)     0           conv_6a_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 4, 4, 64)     4160        conv_6a_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 4, 4, 128)    110720      conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 32)     4640        conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 4, 4, 32)     2080        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# inception_3a (Concatenate)      (None, 4, 4, 256)    0           conv2d[0][0]
#                                                                  conv2d_2[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 96)     24672       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 4, 4, 16)     4112        inception_3a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 4, 4, 256)    0           inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 4, 4, 64)     16448       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 128)    110720      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 32)     4640        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 32)     8224        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# inception_3aa (Concatenate)     (None, 4, 4, 256)    0           conv2d_7[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 16)     4112        inception_3aa[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 128)    6272        conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 96)     24672       inception_3aa[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 128)    36992       conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 256)    0           inception_3aa[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 4, 4, 64)     16448       inception_3aa[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 4, 4, 32)     8224        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_4a (Concatenate)      (None, 4, 4, 352)    0           conv2d_14[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 4, 4, 16)     5648        inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 4, 4, 128)    6272        conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 4, 4, 96)     33888       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 4, 4, 128)    36992       conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 352)    0           inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 4, 4, 64)     22592       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 4, 4, 32)     11296       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# inception_4aa (Concatenate)     (None, 4, 4, 352)    0           conv2d_24[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 4, 4, 16)     5648        inception_4aa[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 4, 4, 128)    6272        conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 4, 4, 96)     33888       inception_4aa[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 4, 4, 128)    36992       conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 352)    0           inception_4aa[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 4, 4, 64)     22592       inception_4aa[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 4, 4, 32)     11296       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# inception_4aaa (Concatenate)    (None, 4, 4, 352)    0           conv2d_34[0][0]
#                                                                  conv2d_37[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 4, 4, 16)     5648        inception_4aaa[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 4, 4, 96)     33888       inception_4aaa[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 4, 4, 128)    2176        conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 4, 4, 128)    36992       conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_49[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 352)    0           inception_4aaa[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 4, 4, 64)     22592       inception_4aaa[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 4, 4, 32)     11296       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_5a (Concatenate)      (None, 4, 4, 608)    0           conv2d_44[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 4, 4, 16)     9744        inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 4, 4, 96)     58464       inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 4, 4, 128)    2176        conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 4, 4, 128)    36992       conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_58[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 4, 4, 608)    0           inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 4, 4, 64)     38976       inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 4, 4, 32)     19488       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# inception_5aa (Concatenate)     (None, 4, 4, 608)    0           conv2d_53[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_3x3/1 (GlobalAverage (None, 608)          0           inception_5aa[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 608)          0           avg_pool_5_3x3/1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 608)          0           dropout[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 100)          60900       flatten[0][0]
# ==================================================================================================
# Total params: 2,040,596
# Trainable params: 2,040,596
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# <h3><b> Model Compile</b></h3>

# %%
learning_rate = 0.00001
batch_size = 128
lr_decay = 1e-6
#optimization details
opt = optimizers.Adam(lr=learning_rate)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
# Create Checkpoint and Early Stopping
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint("InceptionV2_Adam_Dropout.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='auto', period=1)
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# <h3><b> Train the Model</b><h3>

# %%
history = model.fit(X_train,y_train, validation_data=(X_test,y_test), epochs=150, batch_size=256, callbacks=[checkpoint,early])
# Out:
# Epoch 1/150
# 196/196 [==============================] - ETA: 0s - loss: 4.5662 - accuracy: 0.0170
# Epoch 00001: val_loss improved from inf to 4.47080, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 10s 51ms/step - loss: 4.5662 - accuracy: 0.0170 - val_loss: 4.4708 - val_accuracy: 0.0202
# Epoch 2/150
# 195/196 [============================>.] - ETA: 0s - loss: 4.4155 - accuracy: 0.0262
# Epoch 00002: val_loss improved from 4.47080 to 4.30691, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 46ms/step - loss: 4.4153 - accuracy: 0.0262 - val_loss: 4.3069 - val_accuracy: 0.0378
# Epoch 3/150
# 196/196 [==============================] - ETA: 0s - loss: 4.2840 - accuracy: 0.0389
# Epoch 00003: val_loss improved from 4.30691 to 4.19557, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 46ms/step - loss: 4.2840 - accuracy: 0.0389 - val_loss: 4.1956 - val_accuracy: 0.0513
# Epoch 4/150
# 195/196 [============================>.] - ETA: 0s - loss: 4.1963 - accuracy: 0.0484
# Epoch 00004: val_loss improved from 4.19557 to 4.10706, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 46ms/step - loss: 4.1964 - accuracy: 0.0484 - val_loss: 4.1071 - val_accuracy: 0.0705
# Epoch 5/150
# 196/196 [==============================] - ETA: 0s - loss: 4.1149 - accuracy: 0.0589
# Epoch 00005: val_loss improved from 4.10706 to 4.01695, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 46ms/step - loss: 4.1149 - accuracy: 0.0589 - val_loss: 4.0169 - val_accuracy: 0.0808
# Epoch 6/150
# 196/196 [==============================] - ETA: 0s - loss: 4.0399 - accuracy: 0.0681
# Epoch 00006: val_loss improved from 4.01695 to 3.94193, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 46ms/step - loss: 4.0399 - accuracy: 0.0681 - val_loss: 3.9419 - val_accuracy: 0.0893
# Epoch 7/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.9763 - accuracy: 0.0755
# Epoch 00007: val_loss improved from 3.94193 to 3.87950, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.9762 - accuracy: 0.0755 - val_loss: 3.8795 - val_accuracy: 0.0997
# Epoch 8/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.9233 - accuracy: 0.0856
# Epoch 00008: val_loss improved from 3.87950 to 3.82797, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.9233 - accuracy: 0.0855 - val_loss: 3.8280 - val_accuracy: 0.1094
# Epoch 9/150
# 196/196 [==============================] - ETA: 0s - loss: 3.8850 - accuracy: 0.0888
# Epoch 00009: val_loss improved from 3.82797 to 3.78919, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.8850 - accuracy: 0.0888 - val_loss: 3.7892 - val_accuracy: 0.1165
# Epoch 10/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.8456 - accuracy: 0.0932
# Epoch 00010: val_loss improved from 3.78919 to 3.75088, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.8453 - accuracy: 0.0932 - val_loss: 3.7509 - val_accuracy: 0.1199
# Epoch 11/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.8099 - accuracy: 0.0991
# Epoch 00011: val_loss improved from 3.75088 to 3.71976, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.8102 - accuracy: 0.0991 - val_loss: 3.7198 - val_accuracy: 0.1281
# Epoch 12/150
# 196/196 [==============================] - ETA: 0s - loss: 3.7795 - accuracy: 0.1067
# Epoch 00012: val_loss improved from 3.71976 to 3.69441, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.7795 - accuracy: 0.1067 - val_loss: 3.6944 - val_accuracy: 0.1341
# Epoch 13/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.7462 - accuracy: 0.1090
# Epoch 00013: val_loss improved from 3.69441 to 3.65247, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.7465 - accuracy: 0.1090 - val_loss: 3.6525 - val_accuracy: 0.1417
# Epoch 14/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.7198 - accuracy: 0.1134
# Epoch 00014: val_loss improved from 3.65247 to 3.63488, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.7197 - accuracy: 0.1135 - val_loss: 3.6349 - val_accuracy: 0.1440
# Epoch 15/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.6931 - accuracy: 0.1179
# Epoch 00015: val_loss improved from 3.63488 to 3.60121, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.6929 - accuracy: 0.1179 - val_loss: 3.6012 - val_accuracy: 0.1475
# Epoch 16/150
# 196/196 [==============================] - ETA: 0s - loss: 3.6664 - accuracy: 0.1202
# Epoch 00016: val_loss improved from 3.60121 to 3.58051, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 46ms/step - loss: 3.6664 - accuracy: 0.1202 - val_loss: 3.5805 - val_accuracy: 0.1490
# Epoch 17/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.6481 - accuracy: 0.1267
# Epoch 00017: val_loss improved from 3.58051 to 3.55476, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.6477 - accuracy: 0.1267 - val_loss: 3.5548 - val_accuracy: 0.1531
# Epoch 18/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.6269 - accuracy: 0.1299
# Epoch 00018: val_loss improved from 3.55476 to 3.53495, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.6269 - accuracy: 0.1299 - val_loss: 3.5349 - val_accuracy: 0.1559
# Epoch 19/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.6090 - accuracy: 0.1316
# Epoch 00019: val_loss improved from 3.53495 to 3.51976, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 46ms/step - loss: 3.6090 - accuracy: 0.1315 - val_loss: 3.5198 - val_accuracy: 0.1578
# Epoch 20/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.5894 - accuracy: 0.1351
# Epoch 00020: val_loss improved from 3.51976 to 3.49787, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.5892 - accuracy: 0.1352 - val_loss: 3.4979 - val_accuracy: 0.1609
# Epoch 21/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.5676 - accuracy: 0.1394
# Epoch 00021: val_loss improved from 3.49787 to 3.48230, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 46ms/step - loss: 3.5675 - accuracy: 0.1394 - val_loss: 3.4823 - val_accuracy: 0.1623
# Epoch 22/150
# 196/196 [==============================] - ETA: 0s - loss: 3.5559 - accuracy: 0.1387
# Epoch 00022: val_loss improved from 3.48230 to 3.46703, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.5559 - accuracy: 0.1387 - val_loss: 3.4670 - val_accuracy: 0.1625
# Epoch 23/150
# 196/196 [==============================] - ETA: 0s - loss: 3.5376 - accuracy: 0.1423
# Epoch 00023: val_loss improved from 3.46703 to 3.46092, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 46ms/step - loss: 3.5376 - accuracy: 0.1423 - val_loss: 3.4609 - val_accuracy: 0.1637
# Epoch 24/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.5211 - accuracy: 0.1455
# Epoch 00024: val_loss improved from 3.46092 to 3.44008, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 46ms/step - loss: 3.5216 - accuracy: 0.1455 - val_loss: 3.4401 - val_accuracy: 0.1675
# Epoch 25/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.5117 - accuracy: 0.1475
# Epoch 00025: val_loss did not improve from 3.44008
# 196/196 [==============================] - 9s 46ms/step - loss: 3.5117 - accuracy: 0.1475 - val_loss: 3.4410 - val_accuracy: 0.1690
# Epoch 26/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.4922 - accuracy: 0.1511
# Epoch 00026: val_loss improved from 3.44008 to 3.42176, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.4922 - accuracy: 0.1511 - val_loss: 3.4218 - val_accuracy: 0.1715
# Epoch 27/150
# 196/196 [==============================] - ETA: 0s - loss: 3.4800 - accuracy: 0.1521
# Epoch 00027: val_loss improved from 3.42176 to 3.41535, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 3.4800 - accuracy: 0.1521 - val_loss: 3.4154 - val_accuracy: 0.1719
# Epoch 28/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.4657 - accuracy: 0.1546
# Epoch 00028: val_loss improved from 3.41535 to 3.38788, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.4654 - accuracy: 0.1546 - val_loss: 3.3879 - val_accuracy: 0.1793
# Epoch 29/150
# 196/196 [==============================] - ETA: 0s - loss: 3.4515 - accuracy: 0.1588
# Epoch 00029: val_loss improved from 3.38788 to 3.37674, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.4515 - accuracy: 0.1588 - val_loss: 3.3767 - val_accuracy: 0.1810
# Epoch 30/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.4409 - accuracy: 0.1572
# Epoch 00030: val_loss improved from 3.37674 to 3.36277, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.4410 - accuracy: 0.1570 - val_loss: 3.3628 - val_accuracy: 0.1815
# Epoch 31/150
# 196/196 [==============================] - ETA: 0s - loss: 3.4222 - accuracy: 0.1634
# Epoch 00031: val_loss improved from 3.36277 to 3.34929, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.4222 - accuracy: 0.1634 - val_loss: 3.3493 - val_accuracy: 0.1847
# Epoch 32/150
# 196/196 [==============================] - ETA: 0s - loss: 3.4089 - accuracy: 0.1635
# Epoch 00032: val_loss improved from 3.34929 to 3.33675, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.4089 - accuracy: 0.1635 - val_loss: 3.3368 - val_accuracy: 0.1903
# Epoch 33/150
# 196/196 [==============================] - ETA: 0s - loss: 3.3981 - accuracy: 0.1649
# Epoch 00033: val_loss improved from 3.33675 to 3.32461, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.3981 - accuracy: 0.1649 - val_loss: 3.3246 - val_accuracy: 0.1926
# Epoch 34/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.3845 - accuracy: 0.1689
# Epoch 00034: val_loss improved from 3.32461 to 3.32233, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.3843 - accuracy: 0.1689 - val_loss: 3.3223 - val_accuracy: 0.1879
# Epoch 35/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.3680 - accuracy: 0.1724
# Epoch 00035: val_loss improved from 3.32233 to 3.30298, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.3682 - accuracy: 0.1723 - val_loss: 3.3030 - val_accuracy: 0.1919
# Epoch 36/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.3552 - accuracy: 0.1723
# Epoch 00036: val_loss improved from 3.30298 to 3.29459, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.3555 - accuracy: 0.1722 - val_loss: 3.2946 - val_accuracy: 0.1939
# Epoch 37/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.3470 - accuracy: 0.1756
# Epoch 00037: val_loss improved from 3.29459 to 3.27625, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.3469 - accuracy: 0.1756 - val_loss: 3.2763 - val_accuracy: 0.1983
# Epoch 38/150
# 196/196 [==============================] - ETA: 0s - loss: 3.3364 - accuracy: 0.1764
# Epoch 00038: val_loss improved from 3.27625 to 3.26483, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.3364 - accuracy: 0.1764 - val_loss: 3.2648 - val_accuracy: 0.2003
# Epoch 39/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.3188 - accuracy: 0.1797
# Epoch 00039: val_loss improved from 3.26483 to 3.25393, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.3187 - accuracy: 0.1798 - val_loss: 3.2539 - val_accuracy: 0.2015
# Epoch 40/150
# 196/196 [==============================] - ETA: 0s - loss: 3.3061 - accuracy: 0.1803
# Epoch 00040: val_loss improved from 3.25393 to 3.24196, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.3061 - accuracy: 0.1803 - val_loss: 3.2420 - val_accuracy: 0.2008
# Epoch 41/150
# 196/196 [==============================] - ETA: 0s - loss: 3.2904 - accuracy: 0.1840
# Epoch 00041: val_loss improved from 3.24196 to 3.23639, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.2904 - accuracy: 0.1840 - val_loss: 3.2364 - val_accuracy: 0.2025
# Epoch 42/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.2790 - accuracy: 0.1854
# Epoch 00042: val_loss improved from 3.23639 to 3.21305, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.2792 - accuracy: 0.1855 - val_loss: 3.2131 - val_accuracy: 0.2096
# Epoch 43/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.2629 - accuracy: 0.1893
# Epoch 00043: val_loss improved from 3.21305 to 3.20258, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.2628 - accuracy: 0.1893 - val_loss: 3.2026 - val_accuracy: 0.2133
# Epoch 44/150
# 196/196 [==============================] - ETA: 0s - loss: 3.2478 - accuracy: 0.1940
# Epoch 00044: val_loss did not improve from 3.20258
# 196/196 [==============================] - 9s 47ms/step - loss: 3.2478 - accuracy: 0.1940 - val_loss: 3.2131 - val_accuracy: 0.2109
# Epoch 45/150
# 196/196 [==============================] - ETA: 0s - loss: 3.2346 - accuracy: 0.1953
# Epoch 00045: val_loss improved from 3.20258 to 3.18411, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 3.2346 - accuracy: 0.1953 - val_loss: 3.1841 - val_accuracy: 0.2198
# Epoch 46/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.2261 - accuracy: 0.1959
# Epoch 00046: val_loss improved from 3.18411 to 3.16815, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 3.2261 - accuracy: 0.1959 - val_loss: 3.1681 - val_accuracy: 0.2190
# Epoch 47/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.2162 - accuracy: 0.2001
# Epoch 00047: val_loss improved from 3.16815 to 3.15237, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.2162 - accuracy: 0.2002 - val_loss: 3.1524 - val_accuracy: 0.2253
# Epoch 48/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.1952 - accuracy: 0.2038
# Epoch 00048: val_loss improved from 3.15237 to 3.14176, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.1952 - accuracy: 0.2039 - val_loss: 3.1418 - val_accuracy: 0.2258
# Epoch 49/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.1869 - accuracy: 0.2036
# Epoch 00049: val_loss improved from 3.14176 to 3.12785, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.1870 - accuracy: 0.2036 - val_loss: 3.1279 - val_accuracy: 0.2254
# Epoch 50/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.1693 - accuracy: 0.2075
# Epoch 00050: val_loss improved from 3.12785 to 3.11427, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 46ms/step - loss: 3.1697 - accuracy: 0.2075 - val_loss: 3.1143 - val_accuracy: 0.2311
# Epoch 51/150
# 196/196 [==============================] - ETA: 0s - loss: 3.1559 - accuracy: 0.2097
# Epoch 00051: val_loss improved from 3.11427 to 3.11223, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.1559 - accuracy: 0.2097 - val_loss: 3.1122 - val_accuracy: 0.2325
# Epoch 52/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.1459 - accuracy: 0.2128
# Epoch 00052: val_loss improved from 3.11223 to 3.09501, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.1457 - accuracy: 0.2127 - val_loss: 3.0950 - val_accuracy: 0.2309
# Epoch 53/150
# 196/196 [==============================] - ETA: 0s - loss: 3.1346 - accuracy: 0.2126
# Epoch 00053: val_loss improved from 3.09501 to 3.08195, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.1346 - accuracy: 0.2126 - val_loss: 3.0819 - val_accuracy: 0.2356
# Epoch 54/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.1202 - accuracy: 0.2162
# Epoch 00054: val_loss did not improve from 3.08195
# 196/196 [==============================] - 9s 46ms/step - loss: 3.1203 - accuracy: 0.2161 - val_loss: 3.0859 - val_accuracy: 0.2324
# Epoch 55/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.1124 - accuracy: 0.2195
# Epoch 00055: val_loss improved from 3.08195 to 3.07506, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.1124 - accuracy: 0.2195 - val_loss: 3.0751 - val_accuracy: 0.2307
# Epoch 56/150
# 196/196 [==============================] - ETA: 0s - loss: 3.0960 - accuracy: 0.2215
# Epoch 00056: val_loss improved from 3.07506 to 3.05246, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 46ms/step - loss: 3.0960 - accuracy: 0.2215 - val_loss: 3.0525 - val_accuracy: 0.2393
# Epoch 57/150
# 196/196 [==============================] - ETA: 0s - loss: 3.0887 - accuracy: 0.2214
# Epoch 00057: val_loss improved from 3.05246 to 3.04121, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.0887 - accuracy: 0.2214 - val_loss: 3.0412 - val_accuracy: 0.2431
# Epoch 58/150
# 196/196 [==============================] - ETA: 0s - loss: 3.0816 - accuracy: 0.2235
# Epoch 00058: val_loss did not improve from 3.04121
# 196/196 [==============================] - 9s 46ms/step - loss: 3.0816 - accuracy: 0.2235 - val_loss: 3.0424 - val_accuracy: 0.2428
# Epoch 59/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.0676 - accuracy: 0.2245
# Epoch 00059: val_loss improved from 3.04121 to 3.02041, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.0672 - accuracy: 0.2245 - val_loss: 3.0204 - val_accuracy: 0.2419
# Epoch 60/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.0621 - accuracy: 0.2277
# Epoch 00060: val_loss improved from 3.02041 to 3.01748, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 3.0614 - accuracy: 0.2278 - val_loss: 3.0175 - val_accuracy: 0.2471
# Epoch 61/150
# 196/196 [==============================] - ETA: 0s - loss: 3.0487 - accuracy: 0.2302
# Epoch 00061: val_loss improved from 3.01748 to 3.00787, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.0487 - accuracy: 0.2302 - val_loss: 3.0079 - val_accuracy: 0.2441
# Epoch 62/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.0394 - accuracy: 0.2334
# Epoch 00062: val_loss did not improve from 3.00787
# 196/196 [==============================] - 9s 46ms/step - loss: 3.0396 - accuracy: 0.2334 - val_loss: 3.0100 - val_accuracy: 0.2458
# Epoch 63/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.0308 - accuracy: 0.2343
# Epoch 00063: val_loss improved from 3.00787 to 2.99721, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.0307 - accuracy: 0.2343 - val_loss: 2.9972 - val_accuracy: 0.2489
# Epoch 64/150
# 196/196 [==============================] - ETA: 0s - loss: 3.0100 - accuracy: 0.2370
# Epoch 00064: val_loss improved from 2.99721 to 2.98777, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.0100 - accuracy: 0.2370 - val_loss: 2.9878 - val_accuracy: 0.2480
# Epoch 65/150
# 196/196 [==============================] - ETA: 0s - loss: 3.0078 - accuracy: 0.2379
# Epoch 00065: val_loss improved from 2.98777 to 2.97663, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 3.0078 - accuracy: 0.2379 - val_loss: 2.9766 - val_accuracy: 0.2536
# Epoch 66/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.9987 - accuracy: 0.2389
# Epoch 00066: val_loss improved from 2.97663 to 2.97438, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.9987 - accuracy: 0.2389 - val_loss: 2.9744 - val_accuracy: 0.2510
# Epoch 67/150
# 196/196 [==============================] - ETA: 0s - loss: 2.9919 - accuracy: 0.2400
# Epoch 00067: val_loss improved from 2.97438 to 2.96208, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.9919 - accuracy: 0.2400 - val_loss: 2.9621 - val_accuracy: 0.2537
# Epoch 68/150
# 196/196 [==============================] - ETA: 0s - loss: 2.9806 - accuracy: 0.2444
# Epoch 00068: val_loss improved from 2.96208 to 2.96094, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.9806 - accuracy: 0.2444 - val_loss: 2.9609 - val_accuracy: 0.2528
# Epoch 69/150
# 196/196 [==============================] - ETA: 0s - loss: 2.9736 - accuracy: 0.2445
# Epoch 00069: val_loss improved from 2.96094 to 2.95451, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.9736 - accuracy: 0.2445 - val_loss: 2.9545 - val_accuracy: 0.2554
# Epoch 70/150
# 196/196 [==============================] - ETA: 0s - loss: 2.9668 - accuracy: 0.2472
# Epoch 00070: val_loss improved from 2.95451 to 2.94895, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.9668 - accuracy: 0.2472 - val_loss: 2.9489 - val_accuracy: 0.2569
# Epoch 71/150
# 196/196 [==============================] - ETA: 0s - loss: 2.9582 - accuracy: 0.2468
# Epoch 00071: val_loss improved from 2.94895 to 2.94300, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.9582 - accuracy: 0.2468 - val_loss: 2.9430 - val_accuracy: 0.2578
# Epoch 72/150
# 196/196 [==============================] - ETA: 0s - loss: 2.9466 - accuracy: 0.2525
# Epoch 00072: val_loss improved from 2.94300 to 2.92827, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.9466 - accuracy: 0.2525 - val_loss: 2.9283 - val_accuracy: 0.2589
# Epoch 73/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.9422 - accuracy: 0.2492
# Epoch 00073: val_loss improved from 2.92827 to 2.92527, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.9424 - accuracy: 0.2490 - val_loss: 2.9253 - val_accuracy: 0.2582
# Epoch 74/150
# 196/196 [==============================] - ETA: 0s - loss: 2.9281 - accuracy: 0.2517
# Epoch 00074: val_loss improved from 2.92527 to 2.92161, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.9281 - accuracy: 0.2517 - val_loss: 2.9216 - val_accuracy: 0.2603
# Epoch 75/150
# 196/196 [==============================] - ETA: 0s - loss: 2.9255 - accuracy: 0.2541
# Epoch 00075: val_loss improved from 2.92161 to 2.91388, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.9255 - accuracy: 0.2541 - val_loss: 2.9139 - val_accuracy: 0.2606
# Epoch 76/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.9126 - accuracy: 0.2577
# Epoch 00076: val_loss did not improve from 2.91388
# 196/196 [==============================] - 9s 46ms/step - loss: 2.9125 - accuracy: 0.2577 - val_loss: 2.9178 - val_accuracy: 0.2602
# Epoch 77/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.9120 - accuracy: 0.2568
# Epoch 00077: val_loss improved from 2.91388 to 2.89511, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.9119 - accuracy: 0.2567 - val_loss: 2.8951 - val_accuracy: 0.2658
# Epoch 78/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8983 - accuracy: 0.2595
# Epoch 00078: val_loss improved from 2.89511 to 2.89479, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.8983 - accuracy: 0.2595 - val_loss: 2.8948 - val_accuracy: 0.2636
# Epoch 79/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8902 - accuracy: 0.2625
# Epoch 00079: val_loss improved from 2.89479 to 2.88440, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.8903 - accuracy: 0.2625 - val_loss: 2.8844 - val_accuracy: 0.2680
# Epoch 80/150
# 196/196 [==============================] - ETA: 0s - loss: 2.8811 - accuracy: 0.2619
# Epoch 00080: val_loss did not improve from 2.88440
# 196/196 [==============================] - 9s 48ms/step - loss: 2.8811 - accuracy: 0.2619 - val_loss: 2.8925 - val_accuracy: 0.2653
# Epoch 81/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8810 - accuracy: 0.2624
# Epoch 00081: val_loss did not improve from 2.88440
# 196/196 [==============================] - 9s 47ms/step - loss: 2.8814 - accuracy: 0.2624 - val_loss: 2.8862 - val_accuracy: 0.2675
# Epoch 82/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8689 - accuracy: 0.2671
# Epoch 00082: val_loss improved from 2.88440 to 2.87142, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.8686 - accuracy: 0.2672 - val_loss: 2.8714 - val_accuracy: 0.2701
# Epoch 83/150
# 196/196 [==============================] - ETA: 0s - loss: 2.8622 - accuracy: 0.2670
# Epoch 00083: val_loss improved from 2.87142 to 2.85844, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.8622 - accuracy: 0.2670 - val_loss: 2.8584 - val_accuracy: 0.2736
# Epoch 84/150
# 196/196 [==============================] - ETA: 0s - loss: 2.8534 - accuracy: 0.2698
# Epoch 00084: val_loss did not improve from 2.85844
# 196/196 [==============================] - 9s 46ms/step - loss: 2.8534 - accuracy: 0.2698 - val_loss: 2.8649 - val_accuracy: 0.2730
# Epoch 85/150
# 196/196 [==============================] - ETA: 0s - loss: 2.8467 - accuracy: 0.2684
# Epoch 00085: val_loss improved from 2.85844 to 2.85328, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.8467 - accuracy: 0.2684 - val_loss: 2.8533 - val_accuracy: 0.2757
# Epoch 86/150
# 196/196 [==============================] - ETA: 0s - loss: 2.8403 - accuracy: 0.2723
# Epoch 00086: val_loss did not improve from 2.85328
# 196/196 [==============================] - 9s 46ms/step - loss: 2.8403 - accuracy: 0.2723 - val_loss: 2.8659 - val_accuracy: 0.2710
# Epoch 87/150
# 196/196 [==============================] - ETA: 0s - loss: 2.8321 - accuracy: 0.2727
# Epoch 00087: val_loss improved from 2.85328 to 2.85316, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.8321 - accuracy: 0.2727 - val_loss: 2.8532 - val_accuracy: 0.2761
# Epoch 88/150
# 196/196 [==============================] - ETA: 0s - loss: 2.8292 - accuracy: 0.2740
# Epoch 00088: val_loss improved from 2.85316 to 2.83767, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.8292 - accuracy: 0.2740 - val_loss: 2.8377 - val_accuracy: 0.2770
# Epoch 89/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8168 - accuracy: 0.2747
# Epoch 00089: val_loss improved from 2.83767 to 2.82935, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.8172 - accuracy: 0.2745 - val_loss: 2.8293 - val_accuracy: 0.2798
# Epoch 90/150
# 196/196 [==============================] - ETA: 0s - loss: 2.8120 - accuracy: 0.2772
# Epoch 00090: val_loss did not improve from 2.82935
# 196/196 [==============================] - 9s 46ms/step - loss: 2.8120 - accuracy: 0.2772 - val_loss: 2.8309 - val_accuracy: 0.2765
# Epoch 91/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8077 - accuracy: 0.2774
# Epoch 00091: val_loss did not improve from 2.82935
# 196/196 [==============================] - 9s 46ms/step - loss: 2.8074 - accuracy: 0.2775 - val_loss: 2.8406 - val_accuracy: 0.2777
# Epoch 92/150
# 196/196 [==============================] - ETA: 0s - loss: 2.8013 - accuracy: 0.2787
# Epoch 00092: val_loss improved from 2.82935 to 2.81952, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.8013 - accuracy: 0.2787 - val_loss: 2.8195 - val_accuracy: 0.2822
# Epoch 93/150
# 196/196 [==============================] - ETA: 0s - loss: 2.7939 - accuracy: 0.2813
# Epoch 00093: val_loss improved from 2.81952 to 2.81728, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.7939 - accuracy: 0.2813 - val_loss: 2.8173 - val_accuracy: 0.2839
# Epoch 94/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7823 - accuracy: 0.2835
# Epoch 00094: val_loss improved from 2.81728 to 2.80812, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.7820 - accuracy: 0.2836 - val_loss: 2.8081 - val_accuracy: 0.2826
# Epoch 95/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7810 - accuracy: 0.2816
# Epoch 00095: val_loss improved from 2.80812 to 2.80460, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.7808 - accuracy: 0.2817 - val_loss: 2.8046 - val_accuracy: 0.2848
# Epoch 96/150
# 196/196 [==============================] - ETA: 0s - loss: 2.7739 - accuracy: 0.2842
# Epoch 00096: val_loss improved from 2.80460 to 2.79531, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.7739 - accuracy: 0.2842 - val_loss: 2.7953 - val_accuracy: 0.2881
# Epoch 97/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7687 - accuracy: 0.2863
# Epoch 00097: val_loss did not improve from 2.79531
# 196/196 [==============================] - 9s 48ms/step - loss: 2.7686 - accuracy: 0.2864 - val_loss: 2.8136 - val_accuracy: 0.2866
# Epoch 98/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7625 - accuracy: 0.2877
# Epoch 00098: val_loss improved from 2.79531 to 2.79180, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.7625 - accuracy: 0.2877 - val_loss: 2.7918 - val_accuracy: 0.2890
# Epoch 99/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7528 - accuracy: 0.2901
# Epoch 00099: val_loss improved from 2.79180 to 2.78324, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.7529 - accuracy: 0.2901 - val_loss: 2.7832 - val_accuracy: 0.2898
# Epoch 100/150
# 196/196 [==============================] - ETA: 0s - loss: 2.7474 - accuracy: 0.2886
# Epoch 00100: val_loss did not improve from 2.78324
# 196/196 [==============================] - 9s 46ms/step - loss: 2.7474 - accuracy: 0.2886 - val_loss: 2.7923 - val_accuracy: 0.2868
# Epoch 101/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7361 - accuracy: 0.2936
# Epoch 00101: val_loss improved from 2.78324 to 2.77443, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.7367 - accuracy: 0.2935 - val_loss: 2.7744 - val_accuracy: 0.2910
# Epoch 102/150
# 196/196 [==============================] - ETA: 0s - loss: 2.7395 - accuracy: 0.2916
# Epoch 00102: val_loss did not improve from 2.77443
# 196/196 [==============================] - 9s 47ms/step - loss: 2.7395 - accuracy: 0.2916 - val_loss: 2.7775 - val_accuracy: 0.2946
# Epoch 103/150
# 196/196 [==============================] - ETA: 0s - loss: 2.7316 - accuracy: 0.2923
# Epoch 00103: val_loss improved from 2.77443 to 2.76030, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.7316 - accuracy: 0.2923 - val_loss: 2.7603 - val_accuracy: 0.2937
# Epoch 104/150
# 196/196 [==============================] - ETA: 0s - loss: 2.7213 - accuracy: 0.2960
# Epoch 00104: val_loss did not improve from 2.76030
# 196/196 [==============================] - 9s 47ms/step - loss: 2.7213 - accuracy: 0.2960 - val_loss: 2.7618 - val_accuracy: 0.2920
# Epoch 105/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7144 - accuracy: 0.2954
# Epoch 00105: val_loss improved from 2.76030 to 2.75670, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.7149 - accuracy: 0.2953 - val_loss: 2.7567 - val_accuracy: 0.2959
# Epoch 106/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7104 - accuracy: 0.2942
# Epoch 00106: val_loss did not improve from 2.75670
# 196/196 [==============================] - 9s 47ms/step - loss: 2.7105 - accuracy: 0.2941 - val_loss: 2.7608 - val_accuracy: 0.2979
# Epoch 107/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7073 - accuracy: 0.2968
# Epoch 00107: val_loss improved from 2.75670 to 2.74523, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.7072 - accuracy: 0.2968 - val_loss: 2.7452 - val_accuracy: 0.2970
# Epoch 108/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7026 - accuracy: 0.3012
# Epoch 00108: val_loss did not improve from 2.74523
# 196/196 [==============================] - 9s 47ms/step - loss: 2.7030 - accuracy: 0.3012 - val_loss: 2.7463 - val_accuracy: 0.2988
# Epoch 109/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6932 - accuracy: 0.2997
# Epoch 00109: val_loss did not improve from 2.74523
# 196/196 [==============================] - 9s 47ms/step - loss: 2.6932 - accuracy: 0.2997 - val_loss: 2.7512 - val_accuracy: 0.2947
# Epoch 110/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6895 - accuracy: 0.3040
# Epoch 00110: val_loss improved from 2.74523 to 2.73544, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.6895 - accuracy: 0.3040 - val_loss: 2.7354 - val_accuracy: 0.2999
# Epoch 111/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6838 - accuracy: 0.3016
# Epoch 00111: val_loss did not improve from 2.73544
# 196/196 [==============================] - 9s 47ms/step - loss: 2.6836 - accuracy: 0.3016 - val_loss: 2.7404 - val_accuracy: 0.2992
# Epoch 112/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6775 - accuracy: 0.3013
# Epoch 00112: val_loss did not improve from 2.73544
# 196/196 [==============================] - 9s 47ms/step - loss: 2.6775 - accuracy: 0.3013 - val_loss: 2.7427 - val_accuracy: 0.2999
# Epoch 113/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6748 - accuracy: 0.3062
# Epoch 00113: val_loss improved from 2.73544 to 2.72938, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.6748 - accuracy: 0.3062 - val_loss: 2.7294 - val_accuracy: 0.3005
# Epoch 114/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6681 - accuracy: 0.3058
# Epoch 00114: val_loss did not improve from 2.72938
# 196/196 [==============================] - 9s 46ms/step - loss: 2.6681 - accuracy: 0.3058 - val_loss: 2.7300 - val_accuracy: 0.2980
# Epoch 115/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6582 - accuracy: 0.3085
# Epoch 00115: val_loss improved from 2.72938 to 2.72442, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.6585 - accuracy: 0.3084 - val_loss: 2.7244 - val_accuracy: 0.3017
# Epoch 116/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6577 - accuracy: 0.3087
# Epoch 00116: val_loss improved from 2.72442 to 2.71689, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.6577 - accuracy: 0.3087 - val_loss: 2.7169 - val_accuracy: 0.3046
# Epoch 117/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6535 - accuracy: 0.3098
# Epoch 00117: val_loss improved from 2.71689 to 2.71350, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.6535 - accuracy: 0.3098 - val_loss: 2.7135 - val_accuracy: 0.3055
# Epoch 118/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6480 - accuracy: 0.3103
# Epoch 00118: val_loss did not improve from 2.71350
# 196/196 [==============================] - 9s 47ms/step - loss: 2.6478 - accuracy: 0.3103 - val_loss: 2.7225 - val_accuracy: 0.3032
# Epoch 119/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6426 - accuracy: 0.3110
# Epoch 00119: val_loss improved from 2.71350 to 2.70872, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.6426 - accuracy: 0.3110 - val_loss: 2.7087 - val_accuracy: 0.3048
# Epoch 120/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6349 - accuracy: 0.3125
# Epoch 00120: val_loss did not improve from 2.70872
# 196/196 [==============================] - 9s 47ms/step - loss: 2.6349 - accuracy: 0.3125 - val_loss: 2.7121 - val_accuracy: 0.3047
# Epoch 121/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6241 - accuracy: 0.3160
# Epoch 00121: val_loss improved from 2.70872 to 2.70213, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.6238 - accuracy: 0.3161 - val_loss: 2.7021 - val_accuracy: 0.3072
# Epoch 122/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6223 - accuracy: 0.3156
# Epoch 00122: val_loss improved from 2.70213 to 2.70162, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 10s 49ms/step - loss: 2.6223 - accuracy: 0.3156 - val_loss: 2.7016 - val_accuracy: 0.3071
# Epoch 123/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6143 - accuracy: 0.3199
# Epoch 00123: val_loss improved from 2.70162 to 2.68928, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.6147 - accuracy: 0.3200 - val_loss: 2.6893 - val_accuracy: 0.3087
# Epoch 124/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6116 - accuracy: 0.3176
# Epoch 00124: val_loss did not improve from 2.68928
# 196/196 [==============================] - 9s 48ms/step - loss: 2.6121 - accuracy: 0.3174 - val_loss: 2.6955 - val_accuracy: 0.3088
# Epoch 125/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6064 - accuracy: 0.3199
# Epoch 00125: val_loss did not improve from 2.68928
# 196/196 [==============================] - 9s 48ms/step - loss: 2.6064 - accuracy: 0.3199 - val_loss: 2.6963 - val_accuracy: 0.3056
# Epoch 126/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6028 - accuracy: 0.3202
# Epoch 00126: val_loss did not improve from 2.68928
# 196/196 [==============================] - 9s 48ms/step - loss: 2.6028 - accuracy: 0.3202 - val_loss: 2.7013 - val_accuracy: 0.3109
# Epoch 127/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5949 - accuracy: 0.3225
# Epoch 00127: val_loss improved from 2.68928 to 2.67991, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 10s 49ms/step - loss: 2.5953 - accuracy: 0.3224 - val_loss: 2.6799 - val_accuracy: 0.3100
# Epoch 128/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5942 - accuracy: 0.3233
# Epoch 00128: val_loss did not improve from 2.67991
# 196/196 [==============================] - 9s 48ms/step - loss: 2.5943 - accuracy: 0.3232 - val_loss: 2.6883 - val_accuracy: 0.3071
# Epoch 129/150
# 196/196 [==============================] - ETA: 0s - loss: 2.5852 - accuracy: 0.3268
# Epoch 00129: val_loss did not improve from 2.67991
# 196/196 [==============================] - 9s 48ms/step - loss: 2.5852 - accuracy: 0.3268 - val_loss: 2.6969 - val_accuracy: 0.3101
# Epoch 130/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5826 - accuracy: 0.3250
# Epoch 00130: val_loss did not improve from 2.67991
# 196/196 [==============================] - 9s 48ms/step - loss: 2.5827 - accuracy: 0.3249 - val_loss: 2.6808 - val_accuracy: 0.3116
# Epoch 131/150
# 196/196 [==============================] - ETA: 0s - loss: 2.5778 - accuracy: 0.3270
# Epoch 00131: val_loss improved from 2.67991 to 2.66731, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 10s 49ms/step - loss: 2.5778 - accuracy: 0.3270 - val_loss: 2.6673 - val_accuracy: 0.3124
# Epoch 132/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5759 - accuracy: 0.3260
# Epoch 00132: val_loss improved from 2.66731 to 2.66337, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 10s 49ms/step - loss: 2.5760 - accuracy: 0.3261 - val_loss: 2.6634 - val_accuracy: 0.3153
# Epoch 133/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5721 - accuracy: 0.3302
# Epoch 00133: val_loss improved from 2.66337 to 2.65622, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 10s 49ms/step - loss: 2.5726 - accuracy: 0.3301 - val_loss: 2.6562 - val_accuracy: 0.3171
# Epoch 134/150
# 196/196 [==============================] - ETA: 0s - loss: 2.5610 - accuracy: 0.3306
# Epoch 00134: val_loss did not improve from 2.65622
# 196/196 [==============================] - 9s 48ms/step - loss: 2.5610 - accuracy: 0.3306 - val_loss: 2.6604 - val_accuracy: 0.3156
# Epoch 135/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5537 - accuracy: 0.3328
# Epoch 00135: val_loss did not improve from 2.65622
# 196/196 [==============================] - 9s 48ms/step - loss: 2.5536 - accuracy: 0.3327 - val_loss: 2.6589 - val_accuracy: 0.3159
# Epoch 136/150
# 196/196 [==============================] - ETA: 0s - loss: 2.5535 - accuracy: 0.3312
# Epoch 00136: val_loss did not improve from 2.65622
# 196/196 [==============================] - 9s 48ms/step - loss: 2.5535 - accuracy: 0.3312 - val_loss: 2.6595 - val_accuracy: 0.3149
# Epoch 137/150
# 196/196 [==============================] - ETA: 0s - loss: 2.5459 - accuracy: 0.3319
# Epoch 00137: val_loss improved from 2.65622 to 2.64819, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.5459 - accuracy: 0.3319 - val_loss: 2.6482 - val_accuracy: 0.3196
# Epoch 138/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5460 - accuracy: 0.3326
# Epoch 00138: val_loss did not improve from 2.64819
# 196/196 [==============================] - 9s 48ms/step - loss: 2.5453 - accuracy: 0.3326 - val_loss: 2.6563 - val_accuracy: 0.3180
# Epoch 139/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5365 - accuracy: 0.3339
# Epoch 00139: val_loss improved from 2.64819 to 2.64564, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.5362 - accuracy: 0.3340 - val_loss: 2.6456 - val_accuracy: 0.3172
# Epoch 140/150
# 196/196 [==============================] - ETA: 0s - loss: 2.5352 - accuracy: 0.3339
# Epoch 00140: val_loss did not improve from 2.64564
# 196/196 [==============================] - 9s 47ms/step - loss: 2.5352 - accuracy: 0.3339 - val_loss: 2.6533 - val_accuracy: 0.3141
# Epoch 141/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5311 - accuracy: 0.3345
# Epoch 00141: val_loss did not improve from 2.64564
# 196/196 [==============================] - 9s 47ms/step - loss: 2.5308 - accuracy: 0.3344 - val_loss: 2.6479 - val_accuracy: 0.3152
# Epoch 142/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5262 - accuracy: 0.3373
# Epoch 00142: val_loss improved from 2.64564 to 2.64012, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.5263 - accuracy: 0.3372 - val_loss: 2.6401 - val_accuracy: 0.3186
# Epoch 143/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5213 - accuracy: 0.3402
# Epoch 00143: val_loss did not improve from 2.64012
# 196/196 [==============================] - 9s 47ms/step - loss: 2.5217 - accuracy: 0.3401 - val_loss: 2.6428 - val_accuracy: 0.3207
# Epoch 144/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5171 - accuracy: 0.3364
# Epoch 00144: val_loss did not improve from 2.64012
# 196/196 [==============================] - 9s 47ms/step - loss: 2.5169 - accuracy: 0.3365 - val_loss: 2.6411 - val_accuracy: 0.3202
# Epoch 145/150
# 196/196 [==============================] - ETA: 0s - loss: 2.5094 - accuracy: 0.3400
# Epoch 00145: val_loss improved from 2.64012 to 2.63269, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.5094 - accuracy: 0.3400 - val_loss: 2.6327 - val_accuracy: 0.3216
# Epoch 146/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5024 - accuracy: 0.3432
# Epoch 00146: val_loss did not improve from 2.63269
# 196/196 [==============================] - 9s 47ms/step - loss: 2.5022 - accuracy: 0.3432 - val_loss: 2.6382 - val_accuracy: 0.3219
# Epoch 147/150
# 196/196 [==============================] - ETA: 0s - loss: 2.4999 - accuracy: 0.3419
# Epoch 00147: val_loss did not improve from 2.63269
# 196/196 [==============================] - 9s 47ms/step - loss: 2.4999 - accuracy: 0.3419 - val_loss: 2.6328 - val_accuracy: 0.3208
# Epoch 148/150
# 196/196 [==============================] - ETA: 0s - loss: 2.4974 - accuracy: 0.3450
# Epoch 00148: val_loss improved from 2.63269 to 2.62262, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 47ms/step - loss: 2.4974 - accuracy: 0.3450 - val_loss: 2.6226 - val_accuracy: 0.3234
# Epoch 149/150
# 196/196 [==============================] - ETA: 0s - loss: 2.4900 - accuracy: 0.3462
# Epoch 00149: val_loss did not improve from 2.62262
# 196/196 [==============================] - 9s 47ms/step - loss: 2.4900 - accuracy: 0.3462 - val_loss: 2.6264 - val_accuracy: 0.3202
# Epoch 150/150
# 196/196 [==============================] - ETA: 0s - loss: 2.4849 - accuracy: 0.3465
# Epoch 00150: val_loss improved from 2.62262 to 2.62111, saving model to InceptionV2_Adam_Dropout.h5
# 196/196 [==============================] - 9s 48ms/step - loss: 2.4849 - accuracy: 0.3465 - val_loss: 2.6211 - val_accuracy: 0.3271

# %% [markdown]
# <h3><b> Graphs</b></h3>

# %%
import matplotlib.pyplot as plt

history_dict = history.history
print(history_dict.keys())
accuracy_values = history_dict['accuracy']
val_accuracy_values = history_dict['val_accuracy']

epochs = range(1, len(history_dict['accuracy']) + 1)

plt.plot(epochs, accuracy_values, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy_values, 'b', label='Validation loss')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

history_dict = history.history
print(history_dict.keys())
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(history_dict['accuracy']) + 1)

plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# <h3><b> Metric Calculation</b></h3>

# %%
model1 = Model(input_layer,  output)
model1.load_weights("./InceptionV2_Adam_Dropout.h5")
#optimization details
learning_rate = 0.0001
batch_size = 128
lr_decay = 1e-6
#optimization details
opt = optimizers.Adam(lr=learning_rate)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'])

# Test the model
model.predict(X_test).argmax(-1)

y_true = y_test.argmax(-1)
y_pred = model.predict(X_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# Prec: 0.3148704671888079
# Recall: 0.3271
# Accuracy: 0.3271

# %% [markdown]
# <h3><b> References</b></h3>

# %%
#https://www.analyticsvidhya.com/blog/2018/10/understanding-inception-network-from-scratch/
#https://static.googleusercontent.com/media/research.google.com/en//pubs/archive/43022.pdf
