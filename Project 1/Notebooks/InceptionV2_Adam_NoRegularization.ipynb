# %% [markdown]
# <h3><b> Importing Library</b></h3>

# %%
# Importing Libraries
from __future__ import print_function
import os
import math 
import cv2 
import tensorflow as tf
import keras
from keras import backend as K
import numpy as np
from keras.datasets import cifar100
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras import optimizers
from keras.utils import np_utils
from keras.optimizers import SGD 
from keras.callbacks import LearningRateScheduler
from keras import regularizers
from matplotlib import pyplot
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from keras.models import Model
from keras.layers import Conv2D, MaxPool2D, Dropout, Dense, Input, concatenate, GlobalAveragePooling2D, AveragePooling2D,Flatten

# %% [markdown]
# <h3><b> Importing Dataset</b><h3>

# %%
# Load dataset
(X_train, y_train), (X_test, y_test) = cifar100.load_data()
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 4s 0us/step
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# <h3><b> Preprocessing of the dataset</b></h3>

# %%
# Normalize the dataset
X_train = X_train/255
X_test = X_test/255

# %%
#Converting the testing and training dataset into float
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# Convert training and test labels to one hot matrices
y_train = keras.utils.to_categorical(y_train, 100)
y_test = keras.utils.to_categorical(y_test, 100)
print(y_train.shape)
# Out:
# (50000, 100)

# %% [markdown]
# <h3><b> Model Architecure</b></h3>

# %%
def inception_moduleA(x,
                     filters_1x1,
                     filters_3x3_reduce,
                     filters_3x3,
                     filters_5x5_reduce,
                     filters_3x3a,
                      filters_3x3b,
                  
                     filters_pool_proj,
                     name=None):
    
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='elu')(x)
    
    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='elu')(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='elu')(conv_3x3)

    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='elu')(x)
    conv_3x3a = Conv2D(filters_3x3a, (3, 3), padding='same', activation='elu')(conv_5x5)
    conv_3x3b = Conv2D(filters_3x3b, (3, 3), padding='same', activation='elu')(conv_3x3a)
    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='elu')(pool_proj)

    output = concatenate([conv_1x1, conv_3x3, conv_3x3a, pool_proj], axis=-1, name=name)
    
    return output


def inception_moduleB(x,
                     filters_1x1modb,
                     filters_3x3_reducemodb,
                     filters_1x3modb,
                     filters_3x1modb,
                     filters_5x5_reducemodb,
                     filters_1x3amodb,
                      filters_3x1amodb,
                     filters_1x3bmodb,
                      filters_3x1bmodb,
                  
                     filters_pool_proj,
                     name=None):
    
    conv_1x1modb = Conv2D(filters_1x1modb, (1, 1), padding='same', activation='elu')(x)
    
    conv_3x3modb = Conv2D(filters_3x3_reducemodb, (1, 1), padding='same', activation='elu')(x)
    conv_1x3modb = Conv2D(filters_1x3modb, (1, 3), padding='same', activation='elu')(conv_3x3modb)
    conv_3x1modb = Conv2D(filters_3x1modb, (3, 1), padding='same', activation='elu')(conv_1x3modb)

    conv_5x5modb = Conv2D(filters_5x5_reducemodb, (1, 1), padding='same', activation='elu')(x)
    conv_1x3amodb = Conv2D(filters_1x3amodb, (1, 3), padding='same', activation='elu')(conv_5x5modb)
    conv_3x1amodb = Conv2D(filters_3x1amodb, (3, 1), padding='same', activation='elu')(conv_1x3amodb)
    conv_1x3bmodb = Conv2D(filters_1x3bmodb, (1, 3), padding='same', activation='elu')(conv_3x1amodb)
    conv_3x1bmodb = Conv2D(filters_3x1bmodb, (3, 1), padding='same', activation='elu')(conv_1x3bmodb)


    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)


    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='elu')(pool_proj)

    output = concatenate([conv_1x1modb, conv_3x1modb, conv_3x1bmodb, pool_proj], axis=-1, name=name)
    
    return output


def inception_moduleC(x,
                     filters_1x1modc,
                      filters_3x3_reducemodc,
                     filters_1x3modc,
                      filters_3x1modc,
                     filters_5x5_reducemodc,
                        filters_3x3amodc,
                      filters_1x3amodc,
                       filters_3x1amodc,
                      
                   
                     filters_pool_proj,
                     name=None):
    
    conv_1x1modc = Conv2D(filters_1x1modc, (1, 1), padding='same', activation='elu')(x)
    
    conv_3x3modc = Conv2D(filters_3x3_reducemodc, (1, 1), padding='same', activation='elu')(x)
    conv_1x3modc = Conv2D(filters_1x3modc, (1, 3), padding='same', activation='elu')(conv_3x3modc)
    conv_3x1modc = Conv2D(filters_3x1modc, (3, 1), padding='same', activation='elu')(conv_1x3modc)

    conv_5x5modc = Conv2D(filters_5x5_reducemodc, (1, 1), padding='same', activation='elu')(x)
    conv_3x3amodc = Conv2D(filters_3x3amodc, (1, 1), padding='same', activation='elu')(conv_5x5modc)

    conv_1x3amodc = Conv2D(filters_1x3amodc, (1, 3), padding='same', activation='elu')(conv_3x3amodc)
    conv_3x1amodc = Conv2D(filters_3x1amodc, (3, 1), padding='same', activation='elu')(conv_1x3amodc)



    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)


    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='elu')(pool_proj)

    output = concatenate([conv_1x1modc,conv_1x3modc, conv_3x1modc, conv_1x3amodc,conv_3x1amodc, pool_proj], axis=-1, name=name)
    
    return output

# %%
input_layer = Input(shape=(32, 32, 3))

x = Conv2D(64, (3, 3), padding='same', strides=(2, 2), activation='elu', name='conv_1a_3x3/2')(input_layer)
x = Conv2D(64, (3, 3), padding='same', strides=(1, 1), activation='elu', name='conv_2a_3x3/1')(x)
x = Conv2D(64, (3, 3), padding='same', strides=(1, 1), activation='elu', name='conv_3a_3x3/1')(x)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_2_3x3/2')(x)
x = Conv2D(64, (3, 3), padding='same', strides=(1, 1), activation='elu', name='conv_4a_3x3/1')(x)
x = Conv2D(64, (3, 3), padding='same', strides=(2, 2), activation='elu', name='conv_5a_3x3/2')(x)
x = Conv2D(64, (3, 3), padding='same', strides=(1, 1), activation='elu', name='conv_6a_3x3/1')(x)

x = inception_moduleA(x,
                     filters_1x1=64,
                     filters_3x3_reduce=96,
                     filters_3x3=128,
                     filters_5x5_reduce=16,
                     filters_3x3a=32,
                     filters_3x3b=32,
                     filters_pool_proj=32,
                     name='inception_3a')
x = inception_moduleA(x,
                     filters_1x1=64,
                     filters_3x3_reduce=96,
                     filters_3x3=128,
                     filters_5x5_reduce=16,
                     filters_3x3a=32,
                     filters_3x3b=32,
                     filters_pool_proj=32,
                     name='inception_3aa')

#I am commenting the numbers of times module A, ModuleB is called as it is helping to increase my accuracy.In original InceptionV2 architecture ModuleA is called
#3 times, ModuleB is called 5 times and ModuleC is called 2 times:-
# x = inception_moduleA(x,
#                      filters_1x1=64,
#                      filters_3x3_reduce=96,
#                      filters_3x3=128,
#                      filters_5x5_reduce=16,
#                      filters_3x3a=32,
#                      filters_3x3b=32,
#                      filters_pool_proj=32,
#                      name='inception_3aaa')

x = inception_moduleB(x,
                     filters_1x1modb=64,
                     filters_3x3_reducemodb=96,
                     filters_1x3modb=128,
                     filters_3x1modb=128,
                     filters_5x5_reducemodb=16,
                     filters_1x3amodb=128,
                     filters_3x1amodb=128,
                     filters_1x3bmodb=128,
                     filters_3x1bmodb=128,
                   filters_pool_proj=32,
                     name='inception_4a')
x = inception_moduleB(x,
                     filters_1x1modb=64,
                     filters_3x3_reducemodb=96,
                     filters_1x3modb=128,
                     filters_3x1modb=128,
                     filters_5x5_reducemodb=16,
                     filters_1x3amodb=128,
                     filters_3x1amodb=128,
                     filters_1x3bmodb=128,
                     filters_3x1bmodb=128,
                     filters_pool_proj=32,
                     name='inception_4aa')
x = inception_moduleB(x,
                     filters_1x1modb=64,
                     filters_3x3_reducemodb=96,
                     filters_1x3modb=128,
                     filters_3x1modb=128,
                     filters_5x5_reducemodb=16,
                     filters_1x3amodb=128,
                     filters_3x1amodb=128,
                     filters_1x3bmodb=128,
                     filters_3x1bmodb=128,
                      filters_pool_proj=32,
             
                     name='inception_4aaa')
#I am commenting the numbers of times module A, ModuleB is called as it is helping to increase my accuracy.In original InceptionV2 architecture ModuleA is called
#3 times, ModuleB is called 5 times and ModuleC is called 2 times:-
# x = inception_moduleB(x,
#                      filters_1x1modb=64,
#                      filters_3x3_reducemodb=96,
#                      filters_1x3modb=128,
#                      filters_3x1modb=128,
#                      filters_5x5_reducemodb=16,
#                      filters_1x3amodb=128,
#                      filters_3x1amodb=128,
#                      filters_1x3bmodb=128,
#                      filters_3x1bmodb=128,
#                      filters_pool_proj=32,
#                      name='inception_4aaaa')
# x = inception_moduleB(x,
#                      filters_1x1modb=64,
#                      filters_3x3_reducemodb=96,
#                      filters_1x3modb=128,
#                      filters_3x1modb=128,
#                      filters_5x5_reducemodb=16,
#                      filters_1x3amodb=128,
#                      filters_3x1amodb=128,
#                      filters_1x3bmodb=128,
#                      filters_3x1bmodb=128,
#                      filters_pool_proj=32,
#                      name='inception_4aaaaa')

x = inception_moduleC(x,
                     filters_1x1modc=64,
                     filters_3x3_reducemodc=96,
                     filters_1x3modc=128,
                     filters_3x1modc=128,
                     filters_5x5_reducemodc=16,
                     filters_3x3amodc=128,
                     filters_1x3amodc=128,
                     filters_3x1amodc=128,
                     filters_pool_proj=32,
                    
                     name='inception_5a')
x = inception_moduleC(x,
                     filters_1x1modc=64,
                     filters_3x3_reducemodc=96,
                     filters_1x3modc=128,
                     filters_3x1modc=128,
                     filters_5x5_reducemodc=16,
                     filters_3x3amodc=128,
                     filters_1x3amodc=128,
                     filters_3x1amodc=128,
                     filters_pool_proj=32,
             
                     name='inception_5aa')

x = GlobalAveragePooling2D(name='avg_pool_5_3x3/1')(x)
# x = Dropout(0.4)(x)
x = Flatten()(x)
output = Dense(100, activation='softmax', name='output')(x)

# %%
model = Model(input_layer,  output)

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv_1a_3x3/2 (Conv2D)          (None, 16, 16, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv_2a_3x3/1 (Conv2D)          (None, 16, 16, 64)   36928       conv_1a_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv_3a_3x3/1 (Conv2D)          (None, 16, 16, 64)   36928       conv_2a_3x3/1[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 8, 8, 64)     0           conv_3a_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv_4a_3x3/1 (Conv2D)          (None, 8, 8, 64)     36928       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv_5a_3x3/2 (Conv2D)          (None, 4, 4, 64)     36928       conv_4a_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv_6a_3x3/1 (Conv2D)          (None, 4, 4, 64)     36928       conv_5a_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 4, 4, 96)     6240        conv_6a_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 4, 4, 16)     1040        conv_6a_3x3/1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 4, 4, 64)     0           conv_6a_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 4, 4, 64)     4160        conv_6a_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 4, 4, 128)    110720      conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 32)     4640        conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 4, 4, 32)     2080        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# inception_3a (Concatenate)      (None, 4, 4, 256)    0           conv2d[0][0]
#                                                                  conv2d_2[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 96)     24672       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 4, 4, 16)     4112        inception_3a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 4, 4, 256)    0           inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 4, 4, 64)     16448       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 128)    110720      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 32)     4640        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 32)     8224        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# inception_3aa (Concatenate)     (None, 4, 4, 256)    0           conv2d_7[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 16)     4112        inception_3aa[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 128)    6272        conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 96)     24672       inception_3aa[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 128)    36992       conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 256)    0           inception_3aa[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 4, 4, 64)     16448       inception_3aa[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 4, 4, 32)     8224        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_4a (Concatenate)      (None, 4, 4, 352)    0           conv2d_14[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 4, 4, 16)     5648        inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 4, 4, 128)    6272        conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 4, 4, 96)     33888       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 4, 4, 128)    36992       conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 352)    0           inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 4, 4, 64)     22592       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 4, 4, 32)     11296       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# inception_4aa (Concatenate)     (None, 4, 4, 352)    0           conv2d_24[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 4, 4, 16)     5648        inception_4aa[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 4, 4, 128)    6272        conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 4, 4, 96)     33888       inception_4aa[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 4, 4, 128)    36992       conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 352)    0           inception_4aa[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 4, 4, 64)     22592       inception_4aa[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 4, 4, 32)     11296       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# inception_4aaa (Concatenate)    (None, 4, 4, 352)    0           conv2d_34[0][0]
#                                                                  conv2d_37[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 4, 4, 16)     5648        inception_4aaa[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 4, 4, 96)     33888       inception_4aaa[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 4, 4, 128)    2176        conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 4, 4, 128)    36992       conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_49[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 352)    0           inception_4aaa[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 4, 4, 64)     22592       inception_4aaa[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 4, 4, 32)     11296       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_5a (Concatenate)      (None, 4, 4, 608)    0           conv2d_44[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 4, 4, 16)     9744        inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 4, 4, 96)     58464       inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 4, 4, 128)    2176        conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 4, 4, 128)    36992       conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_58[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 4, 4, 608)    0           inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 4, 4, 64)     38976       inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 4, 4, 128)    49280       conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 4, 4, 32)     19488       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# inception_5aa (Concatenate)     (None, 4, 4, 608)    0           conv2d_53[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_3x3/1 (GlobalAverage (None, 608)          0           inception_5aa[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 608)          0           avg_pool_5_3x3/1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 100)          60900       flatten[0][0]
# ==================================================================================================
# Total params: 2,040,596
# Trainable params: 2,040,596
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# <h3><b> Model Compile</b></h3>

# %%
learning_rate = 0.00001
batch_size = 128
lr_decay = 1e-6
#optimization details
opt = optimizers.Adam(lr=learning_rate)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
# Create Checkpoint and Early Stopping
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint("InceptionV2_Adam_NoRegularization.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='auto', period=1)
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# <h3><b> Train the Model</b><h3>

# %%
history = model.fit(X_train,y_train, validation_data=(X_test,y_test), epochs=150, batch_size=256, callbacks=[checkpoint,early])
# Out:
# Epoch 1/150
# 196/196 [==============================] - ETA: 0s - loss: 4.5363 - accuracy: 0.0195
# Epoch 00001: val_loss improved from inf to 4.42639, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 56ms/step - loss: 4.5363 - accuracy: 0.0195 - val_loss: 4.4264 - val_accuracy: 0.0221
# Epoch 2/150
# 195/196 [============================>.] - ETA: 0s - loss: 4.3422 - accuracy: 0.0315
# Epoch 00002: val_loss improved from 4.42639 to 4.25457, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 51ms/step - loss: 4.3421 - accuracy: 0.0315 - val_loss: 4.2546 - val_accuracy: 0.0434
# Epoch 3/150
# 195/196 [============================>.] - ETA: 0s - loss: 4.1901 - accuracy: 0.0515
# Epoch 00003: val_loss improved from 4.25457 to 4.13833, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 52ms/step - loss: 4.1899 - accuracy: 0.0515 - val_loss: 4.1383 - val_accuracy: 0.0570
# Epoch 4/150
# 195/196 [============================>.] - ETA: 0s - loss: 4.1056 - accuracy: 0.0639
# Epoch 00004: val_loss improved from 4.13833 to 4.07233, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 52ms/step - loss: 4.1053 - accuracy: 0.0639 - val_loss: 4.0723 - val_accuracy: 0.0697
# Epoch 5/150
# 195/196 [============================>.] - ETA: 0s - loss: 4.0362 - accuracy: 0.0739
# Epoch 00005: val_loss improved from 4.07233 to 3.99687, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 4.0359 - accuracy: 0.0738 - val_loss: 3.9969 - val_accuracy: 0.0766
# Epoch 6/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.9659 - accuracy: 0.0840
# Epoch 00006: val_loss improved from 3.99687 to 3.94664, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 3.9661 - accuracy: 0.0839 - val_loss: 3.9466 - val_accuracy: 0.0865
# Epoch 7/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.9160 - accuracy: 0.0905
# Epoch 00007: val_loss improved from 3.94664 to 3.89916, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 3.9158 - accuracy: 0.0906 - val_loss: 3.8992 - val_accuracy: 0.0891
# Epoch 8/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.8768 - accuracy: 0.0949
# Epoch 00008: val_loss improved from 3.89916 to 3.87229, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 3.8769 - accuracy: 0.0949 - val_loss: 3.8723 - val_accuracy: 0.0938
# Epoch 9/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.8463 - accuracy: 0.1002
# Epoch 00009: val_loss improved from 3.87229 to 3.84017, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.8461 - accuracy: 0.1001 - val_loss: 3.8402 - val_accuracy: 0.0992
# Epoch 10/150
# 196/196 [==============================] - ETA: 0s - loss: 3.8173 - accuracy: 0.1041
# Epoch 00010: val_loss improved from 3.84017 to 3.81862, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 52ms/step - loss: 3.8173 - accuracy: 0.1041 - val_loss: 3.8186 - val_accuracy: 0.1003
# Epoch 11/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.7886 - accuracy: 0.1082
# Epoch 00011: val_loss improved from 3.81862 to 3.78932, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 52ms/step - loss: 3.7886 - accuracy: 0.1082 - val_loss: 3.7893 - val_accuracy: 0.1067
# Epoch 12/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.7631 - accuracy: 0.1118
# Epoch 00012: val_loss improved from 3.78932 to 3.76586, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.7631 - accuracy: 0.1119 - val_loss: 3.7659 - val_accuracy: 0.1116
# Epoch 13/150
# 196/196 [==============================] - ETA: 0s - loss: 3.7371 - accuracy: 0.1141
# Epoch 00013: val_loss improved from 3.76586 to 3.73543, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.7371 - accuracy: 0.1141 - val_loss: 3.7354 - val_accuracy: 0.1152
# Epoch 14/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.7109 - accuracy: 0.1199
# Epoch 00014: val_loss improved from 3.73543 to 3.72584, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.7112 - accuracy: 0.1199 - val_loss: 3.7258 - val_accuracy: 0.1178
# Epoch 15/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.6888 - accuracy: 0.1226
# Epoch 00015: val_loss improved from 3.72584 to 3.68829, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.6887 - accuracy: 0.1227 - val_loss: 3.6883 - val_accuracy: 0.1240
# Epoch 16/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.6661 - accuracy: 0.1261
# Epoch 00016: val_loss improved from 3.68829 to 3.67518, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.6659 - accuracy: 0.1261 - val_loss: 3.6752 - val_accuracy: 0.1256
# Epoch 17/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.6427 - accuracy: 0.1317
# Epoch 00017: val_loss improved from 3.67518 to 3.64693, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.6423 - accuracy: 0.1318 - val_loss: 3.6469 - val_accuracy: 0.1326
# Epoch 18/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.6225 - accuracy: 0.1334
# Epoch 00018: val_loss improved from 3.64693 to 3.63641, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.6227 - accuracy: 0.1334 - val_loss: 3.6364 - val_accuracy: 0.1310
# Epoch 19/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.6015 - accuracy: 0.1374
# Epoch 00019: val_loss improved from 3.63641 to 3.60647, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.6014 - accuracy: 0.1375 - val_loss: 3.6065 - val_accuracy: 0.1406
# Epoch 20/150
# 196/196 [==============================] - ETA: 0s - loss: 3.5815 - accuracy: 0.1411
# Epoch 00020: val_loss improved from 3.60647 to 3.58886, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.5815 - accuracy: 0.1411 - val_loss: 3.5889 - val_accuracy: 0.1442
# Epoch 21/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.5635 - accuracy: 0.1462
# Epoch 00021: val_loss improved from 3.58886 to 3.57844, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.5635 - accuracy: 0.1462 - val_loss: 3.5784 - val_accuracy: 0.1431
# Epoch 22/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.5426 - accuracy: 0.1484
# Epoch 00022: val_loss improved from 3.57844 to 3.55894, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.5424 - accuracy: 0.1484 - val_loss: 3.5589 - val_accuracy: 0.1484
# Epoch 23/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.5233 - accuracy: 0.1513
# Epoch 00023: val_loss improved from 3.55894 to 3.54403, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.5231 - accuracy: 0.1513 - val_loss: 3.5440 - val_accuracy: 0.1475
# Epoch 24/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.5053 - accuracy: 0.1545
# Epoch 00024: val_loss improved from 3.54403 to 3.54170, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.5054 - accuracy: 0.1546 - val_loss: 3.5417 - val_accuracy: 0.1531
# Epoch 25/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.4890 - accuracy: 0.1571
# Epoch 00025: val_loss improved from 3.54170 to 3.51445, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.4888 - accuracy: 0.1570 - val_loss: 3.5144 - val_accuracy: 0.1528
# Epoch 26/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.4719 - accuracy: 0.1599
# Epoch 00026: val_loss did not improve from 3.51445
# 196/196 [==============================] - 10s 52ms/step - loss: 3.4719 - accuracy: 0.1599 - val_loss: 3.5249 - val_accuracy: 0.1512
# Epoch 27/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.4557 - accuracy: 0.1609
# Epoch 00027: val_loss improved from 3.51445 to 3.47376, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.4554 - accuracy: 0.1610 - val_loss: 3.4738 - val_accuracy: 0.1606
# Epoch 28/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.4356 - accuracy: 0.1657
# Epoch 00028: val_loss improved from 3.47376 to 3.46764, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.4358 - accuracy: 0.1657 - val_loss: 3.4676 - val_accuracy: 0.1637
# Epoch 29/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.4236 - accuracy: 0.1680
# Epoch 00029: val_loss improved from 3.46764 to 3.44701, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.4235 - accuracy: 0.1680 - val_loss: 3.4470 - val_accuracy: 0.1670
# Epoch 30/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.4035 - accuracy: 0.1705
# Epoch 00030: val_loss improved from 3.44701 to 3.42202, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.4035 - accuracy: 0.1705 - val_loss: 3.4220 - val_accuracy: 0.1711
# Epoch 31/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.3875 - accuracy: 0.1748
# Epoch 00031: val_loss improved from 3.42202 to 3.40958, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.3874 - accuracy: 0.1749 - val_loss: 3.4096 - val_accuracy: 0.1721
# Epoch 32/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.3718 - accuracy: 0.1760
# Epoch 00032: val_loss improved from 3.40958 to 3.39427, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.3717 - accuracy: 0.1760 - val_loss: 3.3943 - val_accuracy: 0.1754
# Epoch 33/150
# 196/196 [==============================] - ETA: 0s - loss: 3.3528 - accuracy: 0.1802
# Epoch 00033: val_loss improved from 3.39427 to 3.37998, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.3528 - accuracy: 0.1802 - val_loss: 3.3800 - val_accuracy: 0.1756
# Epoch 34/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.3351 - accuracy: 0.1837
# Epoch 00034: val_loss improved from 3.37998 to 3.36543, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.3357 - accuracy: 0.1836 - val_loss: 3.3654 - val_accuracy: 0.1804
# Epoch 35/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.3209 - accuracy: 0.1854
# Epoch 00035: val_loss improved from 3.36543 to 3.35190, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.3207 - accuracy: 0.1854 - val_loss: 3.3519 - val_accuracy: 0.1845
# Epoch 36/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.3024 - accuracy: 0.1903
# Epoch 00036: val_loss improved from 3.35190 to 3.33938, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.3025 - accuracy: 0.1903 - val_loss: 3.3394 - val_accuracy: 0.1836
# Epoch 37/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.2865 - accuracy: 0.1935
# Epoch 00037: val_loss improved from 3.33938 to 3.33281, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.2866 - accuracy: 0.1935 - val_loss: 3.3328 - val_accuracy: 0.1881
# Epoch 38/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.2708 - accuracy: 0.1953
# Epoch 00038: val_loss improved from 3.33281 to 3.30668, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.2713 - accuracy: 0.1952 - val_loss: 3.3067 - val_accuracy: 0.1920
# Epoch 39/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.2538 - accuracy: 0.1987
# Epoch 00039: val_loss improved from 3.30668 to 3.29869, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.2541 - accuracy: 0.1986 - val_loss: 3.2987 - val_accuracy: 0.1968
# Epoch 40/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.2393 - accuracy: 0.2014
# Epoch 00040: val_loss improved from 3.29869 to 3.28461, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.2391 - accuracy: 0.2015 - val_loss: 3.2846 - val_accuracy: 0.1979
# Epoch 41/150
# 196/196 [==============================] - ETA: 0s - loss: 3.2268 - accuracy: 0.2048
# Epoch 00041: val_loss improved from 3.28461 to 3.26091, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.2268 - accuracy: 0.2048 - val_loss: 3.2609 - val_accuracy: 0.2050
# Epoch 42/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.2127 - accuracy: 0.2082
# Epoch 00042: val_loss improved from 3.26091 to 3.25254, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.2126 - accuracy: 0.2082 - val_loss: 3.2525 - val_accuracy: 0.2009
# Epoch 43/150
# 196/196 [==============================] - ETA: 0s - loss: 3.1971 - accuracy: 0.2112
# Epoch 00043: val_loss improved from 3.25254 to 3.24727, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.1971 - accuracy: 0.2112 - val_loss: 3.2473 - val_accuracy: 0.2020
# Epoch 44/150
# 196/196 [==============================] - ETA: 0s - loss: 3.1842 - accuracy: 0.2129
# Epoch 00044: val_loss improved from 3.24727 to 3.23622, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 52ms/step - loss: 3.1842 - accuracy: 0.2129 - val_loss: 3.2362 - val_accuracy: 0.2060
# Epoch 45/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.1696 - accuracy: 0.2160
# Epoch 00045: val_loss improved from 3.23622 to 3.21168, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.1700 - accuracy: 0.2160 - val_loss: 3.2117 - val_accuracy: 0.2112
# Epoch 46/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.1595 - accuracy: 0.2181
# Epoch 00046: val_loss did not improve from 3.21168
# 196/196 [==============================] - 10s 52ms/step - loss: 3.1595 - accuracy: 0.2181 - val_loss: 3.2177 - val_accuracy: 0.2067
# Epoch 47/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.1472 - accuracy: 0.2197
# Epoch 00047: val_loss improved from 3.21168 to 3.19825, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.1472 - accuracy: 0.2198 - val_loss: 3.1982 - val_accuracy: 0.2142
# Epoch 48/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.1347 - accuracy: 0.2228
# Epoch 00048: val_loss improved from 3.19825 to 3.18389, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.1345 - accuracy: 0.2227 - val_loss: 3.1839 - val_accuracy: 0.2145
# Epoch 49/150
# 196/196 [==============================] - ETA: 0s - loss: 3.1257 - accuracy: 0.2238
# Epoch 00049: val_loss improved from 3.18389 to 3.17609, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.1257 - accuracy: 0.2238 - val_loss: 3.1761 - val_accuracy: 0.2162
# Epoch 50/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.1141 - accuracy: 0.2255
# Epoch 00050: val_loss did not improve from 3.17609
# 196/196 [==============================] - 10s 52ms/step - loss: 3.1137 - accuracy: 0.2255 - val_loss: 3.1808 - val_accuracy: 0.2173
# Epoch 51/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.1049 - accuracy: 0.2284
# Epoch 00051: val_loss improved from 3.17609 to 3.16658, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.1050 - accuracy: 0.2284 - val_loss: 3.1666 - val_accuracy: 0.2199
# Epoch 52/150
# 196/196 [==============================] - ETA: 0s - loss: 3.0924 - accuracy: 0.2297
# Epoch 00052: val_loss did not improve from 3.16658
# 196/196 [==============================] - 10s 52ms/step - loss: 3.0924 - accuracy: 0.2297 - val_loss: 3.1688 - val_accuracy: 0.2173
# Epoch 53/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.0813 - accuracy: 0.2315
# Epoch 00053: val_loss improved from 3.16658 to 3.14230, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.0815 - accuracy: 0.2313 - val_loss: 3.1423 - val_accuracy: 0.2234
# Epoch 54/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.0751 - accuracy: 0.2333
# Epoch 00054: val_loss improved from 3.14230 to 3.13783, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.0751 - accuracy: 0.2335 - val_loss: 3.1378 - val_accuracy: 0.2262
# Epoch 55/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.0630 - accuracy: 0.2348
# Epoch 00055: val_loss improved from 3.13783 to 3.13156, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.0627 - accuracy: 0.2348 - val_loss: 3.1316 - val_accuracy: 0.2253
# Epoch 56/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.0556 - accuracy: 0.2356
# Epoch 00056: val_loss improved from 3.13156 to 3.12390, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.0553 - accuracy: 0.2357 - val_loss: 3.1239 - val_accuracy: 0.2275
# Epoch 57/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.0446 - accuracy: 0.2382
# Epoch 00057: val_loss did not improve from 3.12390
# 196/196 [==============================] - 10s 52ms/step - loss: 3.0446 - accuracy: 0.2382 - val_loss: 3.1249 - val_accuracy: 0.2272
# Epoch 58/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.0388 - accuracy: 0.2411
# Epoch 00058: val_loss improved from 3.12390 to 3.12358, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.0387 - accuracy: 0.2411 - val_loss: 3.1236 - val_accuracy: 0.2259
# Epoch 59/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.0291 - accuracy: 0.2422
# Epoch 00059: val_loss improved from 3.12358 to 3.09713, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 3.0290 - accuracy: 0.2422 - val_loss: 3.0971 - val_accuracy: 0.2338
# Epoch 60/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.0206 - accuracy: 0.2430
# Epoch 00060: val_loss did not improve from 3.09713
# 196/196 [==============================] - 10s 53ms/step - loss: 3.0208 - accuracy: 0.2430 - val_loss: 3.1000 - val_accuracy: 0.2287
# Epoch 61/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.0102 - accuracy: 0.2440
# Epoch 00061: val_loss did not improve from 3.09713
# 196/196 [==============================] - 10s 52ms/step - loss: 3.0108 - accuracy: 0.2439 - val_loss: 3.1126 - val_accuracy: 0.2293
# Epoch 62/150
# 195/196 [============================>.] - ETA: 0s - loss: 3.0034 - accuracy: 0.2456
# Epoch 00062: val_loss did not improve from 3.09713
# 196/196 [==============================] - 10s 52ms/step - loss: 3.0036 - accuracy: 0.2456 - val_loss: 3.1261 - val_accuracy: 0.2293
# Epoch 63/150
# 196/196 [==============================] - ETA: 0s - loss: 2.9983 - accuracy: 0.2471
# Epoch 00063: val_loss improved from 3.09713 to 3.08613, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.9983 - accuracy: 0.2471 - val_loss: 3.0861 - val_accuracy: 0.2354
# Epoch 64/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.9863 - accuracy: 0.2490
# Epoch 00064: val_loss improved from 3.08613 to 3.07839, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.9861 - accuracy: 0.2490 - val_loss: 3.0784 - val_accuracy: 0.2359
# Epoch 65/150
# 196/196 [==============================] - ETA: 0s - loss: 2.9804 - accuracy: 0.2507
# Epoch 00065: val_loss did not improve from 3.07839
# 196/196 [==============================] - 10s 52ms/step - loss: 2.9804 - accuracy: 0.2507 - val_loss: 3.0795 - val_accuracy: 0.2347
# Epoch 66/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.9708 - accuracy: 0.2512
# Epoch 00066: val_loss improved from 3.07839 to 3.06159, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.9709 - accuracy: 0.2514 - val_loss: 3.0616 - val_accuracy: 0.2365
# Epoch 67/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.9654 - accuracy: 0.2525
# Epoch 00067: val_loss improved from 3.06159 to 3.05350, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.9651 - accuracy: 0.2527 - val_loss: 3.0535 - val_accuracy: 0.2383
# Epoch 68/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.9592 - accuracy: 0.2527
# Epoch 00068: val_loss improved from 3.05350 to 3.04607, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.9590 - accuracy: 0.2528 - val_loss: 3.0461 - val_accuracy: 0.2401
# Epoch 69/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.9480 - accuracy: 0.2560
# Epoch 00069: val_loss did not improve from 3.04607
# 196/196 [==============================] - 10s 53ms/step - loss: 2.9486 - accuracy: 0.2559 - val_loss: 3.0527 - val_accuracy: 0.2425
# Epoch 70/150
# 196/196 [==============================] - ETA: 0s - loss: 2.9424 - accuracy: 0.2566
# Epoch 00070: val_loss improved from 3.04607 to 3.03143, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.9424 - accuracy: 0.2566 - val_loss: 3.0314 - val_accuracy: 0.2411
# Epoch 71/150
# 196/196 [==============================] - ETA: 0s - loss: 2.9370 - accuracy: 0.2578
# Epoch 00071: val_loss did not improve from 3.03143
# 196/196 [==============================] - 10s 53ms/step - loss: 2.9370 - accuracy: 0.2578 - val_loss: 3.0511 - val_accuracy: 0.2405
# Epoch 72/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.9289 - accuracy: 0.2603
# Epoch 00072: val_loss did not improve from 3.03143
# 196/196 [==============================] - 10s 53ms/step - loss: 2.9281 - accuracy: 0.2604 - val_loss: 3.0409 - val_accuracy: 0.2440
# Epoch 73/150
# 196/196 [==============================] - ETA: 0s - loss: 2.9204 - accuracy: 0.2619
# Epoch 00073: val_loss improved from 3.03143 to 3.02367, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.9204 - accuracy: 0.2619 - val_loss: 3.0237 - val_accuracy: 0.2466
# Epoch 74/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.9165 - accuracy: 0.2619
# Epoch 00074: val_loss improved from 3.02367 to 3.01200, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.9164 - accuracy: 0.2619 - val_loss: 3.0120 - val_accuracy: 0.2459
# Epoch 75/150
# 196/196 [==============================] - ETA: 0s - loss: 2.9039 - accuracy: 0.2635
# Epoch 00075: val_loss improved from 3.01200 to 3.00517, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.9039 - accuracy: 0.2635 - val_loss: 3.0052 - val_accuracy: 0.2501
# Epoch 76/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.9023 - accuracy: 0.2655
# Epoch 00076: val_loss improved from 3.00517 to 3.00096, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.9022 - accuracy: 0.2656 - val_loss: 3.0010 - val_accuracy: 0.2493
# Epoch 77/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8949 - accuracy: 0.2665
# Epoch 00077: val_loss did not improve from 3.00096
# 196/196 [==============================] - 10s 52ms/step - loss: 2.8945 - accuracy: 0.2666 - val_loss: 3.0041 - val_accuracy: 0.2494
# Epoch 78/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8820 - accuracy: 0.2688
# Epoch 00078: val_loss improved from 3.00096 to 2.98606, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.8819 - accuracy: 0.2689 - val_loss: 2.9861 - val_accuracy: 0.2553
# Epoch 79/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8798 - accuracy: 0.2686
# Epoch 00079: val_loss did not improve from 2.98606
# 196/196 [==============================] - 10s 53ms/step - loss: 2.8794 - accuracy: 0.2687 - val_loss: 2.9958 - val_accuracy: 0.2519
# Epoch 80/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8723 - accuracy: 0.2709
# Epoch 00080: val_loss improved from 2.98606 to 2.98562, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.8722 - accuracy: 0.2709 - val_loss: 2.9856 - val_accuracy: 0.2508
# Epoch 81/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8640 - accuracy: 0.2703
# Epoch 00081: val_loss did not improve from 2.98562
# 196/196 [==============================] - 10s 52ms/step - loss: 2.8637 - accuracy: 0.2704 - val_loss: 2.9993 - val_accuracy: 0.2512
# Epoch 82/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8562 - accuracy: 0.2737
# Epoch 00082: val_loss improved from 2.98562 to 2.97306, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.8563 - accuracy: 0.2737 - val_loss: 2.9731 - val_accuracy: 0.2561
# Epoch 83/150
# 196/196 [==============================] - ETA: 0s - loss: 2.8512 - accuracy: 0.2741
# Epoch 00083: val_loss did not improve from 2.97306
# 196/196 [==============================] - 10s 52ms/step - loss: 2.8512 - accuracy: 0.2741 - val_loss: 2.9780 - val_accuracy: 0.2560
# Epoch 84/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8455 - accuracy: 0.2767
# Epoch 00084: val_loss did not improve from 2.97306
# 196/196 [==============================] - 10s 52ms/step - loss: 2.8451 - accuracy: 0.2768 - val_loss: 2.9875 - val_accuracy: 0.2523
# Epoch 85/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8411 - accuracy: 0.2759
# Epoch 00085: val_loss improved from 2.97306 to 2.95733, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.8407 - accuracy: 0.2761 - val_loss: 2.9573 - val_accuracy: 0.2614
# Epoch 86/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8305 - accuracy: 0.2790
# Epoch 00086: val_loss did not improve from 2.95733
# 196/196 [==============================] - 10s 53ms/step - loss: 2.8302 - accuracy: 0.2791 - val_loss: 2.9654 - val_accuracy: 0.2600
# Epoch 87/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8245 - accuracy: 0.2798
# Epoch 00087: val_loss did not improve from 2.95733
# 196/196 [==============================] - 10s 53ms/step - loss: 2.8243 - accuracy: 0.2799 - val_loss: 2.9595 - val_accuracy: 0.2593
# Epoch 88/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8176 - accuracy: 0.2822
# Epoch 00088: val_loss improved from 2.95733 to 2.94955, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.8179 - accuracy: 0.2822 - val_loss: 2.9496 - val_accuracy: 0.2611
# Epoch 89/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8135 - accuracy: 0.2824
# Epoch 00089: val_loss did not improve from 2.94955
# 196/196 [==============================] - 10s 53ms/step - loss: 2.8136 - accuracy: 0.2824 - val_loss: 2.9531 - val_accuracy: 0.2643
# Epoch 90/150
# 196/196 [==============================] - ETA: 0s - loss: 2.8046 - accuracy: 0.2835
# Epoch 00090: val_loss improved from 2.94955 to 2.92951, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.8046 - accuracy: 0.2835 - val_loss: 2.9295 - val_accuracy: 0.2677
# Epoch 91/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.8001 - accuracy: 0.2847
# Epoch 00091: val_loss improved from 2.92951 to 2.92571, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.8002 - accuracy: 0.2848 - val_loss: 2.9257 - val_accuracy: 0.2685
# Epoch 92/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7903 - accuracy: 0.2871
# Epoch 00092: val_loss did not improve from 2.92571
# 196/196 [==============================] - 10s 53ms/step - loss: 2.7907 - accuracy: 0.2870 - val_loss: 2.9563 - val_accuracy: 0.2630
# Epoch 93/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7853 - accuracy: 0.2875
# Epoch 00093: val_loss improved from 2.92571 to 2.92505, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.7851 - accuracy: 0.2875 - val_loss: 2.9251 - val_accuracy: 0.2668
# Epoch 94/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7798 - accuracy: 0.2880
# Epoch 00094: val_loss improved from 2.92505 to 2.91412, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.7797 - accuracy: 0.2882 - val_loss: 2.9141 - val_accuracy: 0.2681
# Epoch 95/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7775 - accuracy: 0.2899
# Epoch 00095: val_loss did not improve from 2.91412
# 196/196 [==============================] - 10s 53ms/step - loss: 2.7774 - accuracy: 0.2900 - val_loss: 2.9142 - val_accuracy: 0.2728
# Epoch 96/150
# 196/196 [==============================] - ETA: 0s - loss: 2.7669 - accuracy: 0.2913
# Epoch 00096: val_loss improved from 2.91412 to 2.91295, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.7669 - accuracy: 0.2913 - val_loss: 2.9129 - val_accuracy: 0.2704
# Epoch 97/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7604 - accuracy: 0.2931
# Epoch 00097: val_loss improved from 2.91295 to 2.90697, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.7599 - accuracy: 0.2932 - val_loss: 2.9070 - val_accuracy: 0.2748
# Epoch 98/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7556 - accuracy: 0.2940
# Epoch 00098: val_loss improved from 2.90697 to 2.90670, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 2.7551 - accuracy: 0.2942 - val_loss: 2.9067 - val_accuracy: 0.2719
# Epoch 99/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7475 - accuracy: 0.2955
# Epoch 00099: val_loss improved from 2.90670 to 2.90496, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.7478 - accuracy: 0.2955 - val_loss: 2.9050 - val_accuracy: 0.2725
# Epoch 100/150
# 196/196 [==============================] - ETA: 0s - loss: 2.7403 - accuracy: 0.2971
# Epoch 00100: val_loss improved from 2.90496 to 2.89449, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.7403 - accuracy: 0.2971 - val_loss: 2.8945 - val_accuracy: 0.2757
# Epoch 101/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7357 - accuracy: 0.2950
# Epoch 00101: val_loss improved from 2.89449 to 2.89290, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.7361 - accuracy: 0.2950 - val_loss: 2.8929 - val_accuracy: 0.2749
# Epoch 102/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7312 - accuracy: 0.2978
# Epoch 00102: val_loss did not improve from 2.89290
# 196/196 [==============================] - 10s 53ms/step - loss: 2.7311 - accuracy: 0.2979 - val_loss: 2.9219 - val_accuracy: 0.2715
# Epoch 103/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7255 - accuracy: 0.2988
# Epoch 00103: val_loss improved from 2.89290 to 2.88846, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.7260 - accuracy: 0.2987 - val_loss: 2.8885 - val_accuracy: 0.2779
# Epoch 104/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7190 - accuracy: 0.3006
# Epoch 00104: val_loss improved from 2.88846 to 2.87360, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.7190 - accuracy: 0.3005 - val_loss: 2.8736 - val_accuracy: 0.2790
# Epoch 105/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7118 - accuracy: 0.3028
# Epoch 00105: val_loss improved from 2.87360 to 2.86883, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.7122 - accuracy: 0.3028 - val_loss: 2.8688 - val_accuracy: 0.2811
# Epoch 106/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.7030 - accuracy: 0.3047
# Epoch 00106: val_loss improved from 2.86883 to 2.86255, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.7029 - accuracy: 0.3046 - val_loss: 2.8625 - val_accuracy: 0.2801
# Epoch 107/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6966 - accuracy: 0.3043
# Epoch 00107: val_loss improved from 2.86255 to 2.85691, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 2.6967 - accuracy: 0.3042 - val_loss: 2.8569 - val_accuracy: 0.2811
# Epoch 108/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6962 - accuracy: 0.3047
# Epoch 00108: val_loss improved from 2.85691 to 2.85469, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 2.6967 - accuracy: 0.3046 - val_loss: 2.8547 - val_accuracy: 0.2853
# Epoch 109/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6912 - accuracy: 0.3054
# Epoch 00109: val_loss improved from 2.85469 to 2.85074, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 2.6912 - accuracy: 0.3054 - val_loss: 2.8507 - val_accuracy: 0.2854
# Epoch 110/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6808 - accuracy: 0.3091
# Epoch 00110: val_loss did not improve from 2.85074
# 196/196 [==============================] - 11s 54ms/step - loss: 2.6810 - accuracy: 0.3091 - val_loss: 2.8527 - val_accuracy: 0.2848
# Epoch 111/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6735 - accuracy: 0.3102
# Epoch 00111: val_loss improved from 2.85074 to 2.84680, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 2.6735 - accuracy: 0.3102 - val_loss: 2.8468 - val_accuracy: 0.2858
# Epoch 112/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6699 - accuracy: 0.3111
# Epoch 00112: val_loss did not improve from 2.84680
# 196/196 [==============================] - 10s 53ms/step - loss: 2.6699 - accuracy: 0.3111 - val_loss: 2.8523 - val_accuracy: 0.2835
# Epoch 113/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6642 - accuracy: 0.3119
# Epoch 00113: val_loss improved from 2.84680 to 2.83221, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.6645 - accuracy: 0.3118 - val_loss: 2.8322 - val_accuracy: 0.2869
# Epoch 114/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6570 - accuracy: 0.3132
# Epoch 00114: val_loss improved from 2.83221 to 2.83107, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.6575 - accuracy: 0.3131 - val_loss: 2.8311 - val_accuracy: 0.2897
# Epoch 115/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6533 - accuracy: 0.3145
# Epoch 00115: val_loss did not improve from 2.83107
# 196/196 [==============================] - 10s 53ms/step - loss: 2.6535 - accuracy: 0.3145 - val_loss: 2.8350 - val_accuracy: 0.2879
# Epoch 116/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6486 - accuracy: 0.3164
# Epoch 00116: val_loss did not improve from 2.83107
# 196/196 [==============================] - 10s 53ms/step - loss: 2.6486 - accuracy: 0.3165 - val_loss: 2.8336 - val_accuracy: 0.2868
# Epoch 117/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6425 - accuracy: 0.3158
# Epoch 00117: val_loss improved from 2.83107 to 2.82879, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 54ms/step - loss: 2.6425 - accuracy: 0.3158 - val_loss: 2.8288 - val_accuracy: 0.2891
# Epoch 118/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6394 - accuracy: 0.3166
# Epoch 00118: val_loss did not improve from 2.82879
# 196/196 [==============================] - 10s 53ms/step - loss: 2.6391 - accuracy: 0.3166 - val_loss: 2.8395 - val_accuracy: 0.2869
# Epoch 119/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6299 - accuracy: 0.3189
# Epoch 00119: val_loss improved from 2.82879 to 2.81745, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 2.6299 - accuracy: 0.3189 - val_loss: 2.8174 - val_accuracy: 0.2902
# Epoch 120/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6265 - accuracy: 0.3192
# Epoch 00120: val_loss improved from 2.81745 to 2.81496, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.6265 - accuracy: 0.3192 - val_loss: 2.8150 - val_accuracy: 0.2915
# Epoch 121/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6192 - accuracy: 0.3213
# Epoch 00121: val_loss did not improve from 2.81496
# 196/196 [==============================] - 10s 53ms/step - loss: 2.6192 - accuracy: 0.3213 - val_loss: 2.8162 - val_accuracy: 0.2925
# Epoch 122/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6157 - accuracy: 0.3210
# Epoch 00122: val_loss improved from 2.81496 to 2.81301, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.6159 - accuracy: 0.3211 - val_loss: 2.8130 - val_accuracy: 0.2917
# Epoch 123/150
# 196/196 [==============================] - ETA: 0s - loss: 2.6088 - accuracy: 0.3232
# Epoch 00123: val_loss improved from 2.81301 to 2.80403, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.6088 - accuracy: 0.3232 - val_loss: 2.8040 - val_accuracy: 0.2940
# Epoch 124/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6057 - accuracy: 0.3245
# Epoch 00124: val_loss did not improve from 2.80403
# 196/196 [==============================] - 10s 53ms/step - loss: 2.6057 - accuracy: 0.3246 - val_loss: 2.8163 - val_accuracy: 0.2939
# Epoch 125/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.6017 - accuracy: 0.3248
# Epoch 00125: val_loss did not improve from 2.80403
# 196/196 [==============================] - 10s 53ms/step - loss: 2.6016 - accuracy: 0.3248 - val_loss: 2.8078 - val_accuracy: 0.2944
# Epoch 126/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5918 - accuracy: 0.3256
# Epoch 00126: val_loss improved from 2.80403 to 2.79910, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.5920 - accuracy: 0.3256 - val_loss: 2.7991 - val_accuracy: 0.2955
# Epoch 127/150
# 196/196 [==============================] - ETA: 0s - loss: 2.5877 - accuracy: 0.3275
# Epoch 00127: val_loss improved from 2.79910 to 2.78751, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 2.5877 - accuracy: 0.3275 - val_loss: 2.7875 - val_accuracy: 0.2997
# Epoch 128/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5839 - accuracy: 0.3279
# Epoch 00128: val_loss did not improve from 2.78751
# 196/196 [==============================] - 10s 53ms/step - loss: 2.5837 - accuracy: 0.3280 - val_loss: 2.7935 - val_accuracy: 0.2970
# Epoch 129/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5739 - accuracy: 0.3303
# Epoch 00129: val_loss did not improve from 2.78751
# 196/196 [==============================] - 10s 53ms/step - loss: 2.5744 - accuracy: 0.3303 - val_loss: 2.7975 - val_accuracy: 0.2959
# Epoch 130/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5742 - accuracy: 0.3316
# Epoch 00130: val_loss did not improve from 2.78751
# 196/196 [==============================] - 10s 53ms/step - loss: 2.5741 - accuracy: 0.3315 - val_loss: 2.7949 - val_accuracy: 0.2966
# Epoch 131/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5659 - accuracy: 0.3322
# Epoch 00131: val_loss did not improve from 2.78751
# 196/196 [==============================] - 10s 53ms/step - loss: 2.5660 - accuracy: 0.3322 - val_loss: 2.7884 - val_accuracy: 0.2987
# Epoch 132/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5624 - accuracy: 0.3329
# Epoch 00132: val_loss improved from 2.78751 to 2.78355, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 2.5621 - accuracy: 0.3329 - val_loss: 2.7835 - val_accuracy: 0.2965
# Epoch 133/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5591 - accuracy: 0.3335
# Epoch 00133: val_loss improved from 2.78355 to 2.77719, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 2.5593 - accuracy: 0.3335 - val_loss: 2.7772 - val_accuracy: 0.3010
# Epoch 134/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5522 - accuracy: 0.3346
# Epoch 00134: val_loss did not improve from 2.77719
# 196/196 [==============================] - 10s 53ms/step - loss: 2.5519 - accuracy: 0.3347 - val_loss: 2.7910 - val_accuracy: 0.3010
# Epoch 135/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5497 - accuracy: 0.3344
# Epoch 00135: val_loss improved from 2.77719 to 2.77176, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.5495 - accuracy: 0.3345 - val_loss: 2.7718 - val_accuracy: 0.3029
# Epoch 136/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5434 - accuracy: 0.3360
# Epoch 00136: val_loss did not improve from 2.77176
# 196/196 [==============================] - 10s 53ms/step - loss: 2.5434 - accuracy: 0.3359 - val_loss: 2.7735 - val_accuracy: 0.3049
# Epoch 137/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5388 - accuracy: 0.3360
# Epoch 00137: val_loss improved from 2.77176 to 2.76471, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 2.5386 - accuracy: 0.3362 - val_loss: 2.7647 - val_accuracy: 0.3018
# Epoch 138/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5335 - accuracy: 0.3392
# Epoch 00138: val_loss improved from 2.76471 to 2.75795, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 2.5336 - accuracy: 0.3391 - val_loss: 2.7579 - val_accuracy: 0.3048
# Epoch 139/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5280 - accuracy: 0.3397
# Epoch 00139: val_loss did not improve from 2.75795
# 196/196 [==============================] - 10s 53ms/step - loss: 2.5280 - accuracy: 0.3397 - val_loss: 2.7669 - val_accuracy: 0.3002
# Epoch 140/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5241 - accuracy: 0.3402
# Epoch 00140: val_loss did not improve from 2.75795
# 196/196 [==============================] - 10s 53ms/step - loss: 2.5244 - accuracy: 0.3401 - val_loss: 2.7604 - val_accuracy: 0.3042
# Epoch 141/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5183 - accuracy: 0.3416
# Epoch 00141: val_loss did not improve from 2.75795
# 196/196 [==============================] - 10s 53ms/step - loss: 2.5185 - accuracy: 0.3416 - val_loss: 2.7617 - val_accuracy: 0.3044
# Epoch 142/150
# 196/196 [==============================] - ETA: 0s - loss: 2.5126 - accuracy: 0.3437
# Epoch 00142: val_loss improved from 2.75795 to 2.75718, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 2.5126 - accuracy: 0.3437 - val_loss: 2.7572 - val_accuracy: 0.3032
# Epoch 143/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5058 - accuracy: 0.3450
# Epoch 00143: val_loss did not improve from 2.75718
# 196/196 [==============================] - 10s 53ms/step - loss: 2.5055 - accuracy: 0.3451 - val_loss: 2.7621 - val_accuracy: 0.3056
# Epoch 144/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.5035 - accuracy: 0.3441
# Epoch 00144: val_loss improved from 2.75718 to 2.74602, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 10s 53ms/step - loss: 2.5035 - accuracy: 0.3441 - val_loss: 2.7460 - val_accuracy: 0.3079
# Epoch 145/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.4983 - accuracy: 0.3463
# Epoch 00145: val_loss did not improve from 2.74602
# 196/196 [==============================] - 10s 53ms/step - loss: 2.4982 - accuracy: 0.3463 - val_loss: 2.7505 - val_accuracy: 0.3070
# Epoch 146/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.4962 - accuracy: 0.3459
# Epoch 00146: val_loss did not improve from 2.74602
# 196/196 [==============================] - 10s 53ms/step - loss: 2.4962 - accuracy: 0.3458 - val_loss: 2.7502 - val_accuracy: 0.3057
# Epoch 147/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.4914 - accuracy: 0.3477
# Epoch 00147: val_loss did not improve from 2.74602
# 196/196 [==============================] - 10s 53ms/step - loss: 2.4910 - accuracy: 0.3478 - val_loss: 2.7507 - val_accuracy: 0.3076
# Epoch 148/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.4873 - accuracy: 0.3479
# Epoch 00148: val_loss improved from 2.74602 to 2.73717, saving model to InceptionV2_Adam_NoRegularization.h5
# 196/196 [==============================] - 11s 54ms/step - loss: 2.4873 - accuracy: 0.3479 - val_loss: 2.7372 - val_accuracy: 0.3092
# Epoch 149/150
# 195/196 [============================>.] - ETA: 0s - loss: 2.4805 - accuracy: 0.3495
# Epoch 00149: val_loss did not improve from 2.73717
# 196/196 [==============================] - 10s 53ms/step - loss: 2.4806 - accuracy: 0.3495 - val_loss: 2.7451 - val_accuracy: 0.3087
# Epoch 150/150
# 196/196 [==============================] - ETA: 0s - loss: 2.4749 - accuracy: 0.3515
# Epoch 00150: val_loss did not improve from 2.73717
# 196/196 [==============================] - 10s 53ms/step - loss: 2.4749 - accuracy: 0.3515 - val_loss: 2.7387 - val_accuracy: 0.3085

# %% [markdown]
# <h3><b> Graphs</b></h3>

# %%
import matplotlib.pyplot as plt

history_dict = history.history
print(history_dict.keys())
accuracy_values = history_dict['accuracy']
val_accuracy_values = history_dict['val_accuracy']

epochs = range(1, len(history_dict['accuracy']) + 1)

plt.plot(epochs, accuracy_values, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy_values, 'b', label='Validation loss')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

history_dict = history.history
print(history_dict.keys())
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(history_dict['accuracy']) + 1)

plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# <h3><b> Metric Calculation</b></h3>

# %%
model1 = Model(input_layer,  output)
model1.load_weights("./InceptionV2_Adam_NoRegularization.h5")
#optimization details
learning_rate = 0.0001
batch_size = 128
lr_decay = 1e-6
#optimization details
opt = optimizers.Adam(lr=learning_rate)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'])

# Test the model
model.predict(X_test).argmax(-1)

y_true = y_test.argmax(-1)
y_pred = model.predict(X_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# Prec: 0.2991708876904299
# Recall: 0.3092
# Accuracy: 0.3092

# %% [markdown]
# <h3><b> References</b></h3>

# %%
#https://www.analyticsvidhya.com/blog/2018/10/understanding-inception-network-from-scratch/
#https://static.googleusercontent.com/media/research.google.com/en//pubs/archive/43022.pdf
